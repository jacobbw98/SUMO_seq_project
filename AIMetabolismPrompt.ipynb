# %%
# !pip install pandas googlesearch-python requests beautifulsoup4 google-generativeai
# Out:
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.12/site-packages (2.3.1)
# Requirement already satisfied: googlesearch-python in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.3.0)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /home/codespace/.local/lib/python3.12/site-packages (4.13.4)
# Requirement already satisfied: google-generativeai in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.8.5)
# Requirement already satisfied: numpy>=1.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests) (2025.7.9)
# Requirement already satisfied: soupsieve>1.2 in /home/codespace/.local/lib/python3.12/site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from beautifulsoup4) (4.14.1)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-generativeai) (2.25.1)
# Requirement already satisfied: google-api-python-client in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-generativeai) (2.181.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-generativeai) (2.40.3)
# Requirement already satisfied: protobuf in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-generativeai) (2.11.7)
# Requirement already satisfied: tqdm in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client->google-generativeai) (0.30.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /home/codespace/.local/lib/python3.12/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic->google-generativeai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic->google-generativeai) (0.4.1)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from googlesearch import search
import time
import google.generativeai as genai
import os

# --- Configure the Gemini API ---
# IMPORTANT: Replace "YOUR_API_KEY" with your actual Google AI API key.
try:
    GOOGLE_API_KEY = "AIzaSyBf9wxJNyxFmf8XDfm85J9gl-5VWHLKlzQ"
    genai.configure(api_key=GOOGLE_API_KEY)
    model = genai.GenerativeModel('gemma-3-27b-it')
    print("✅ Gemini API configured successfully.")
except Exception as e:
    print(f"🔴 Error configuring Gemini API: {e}")
    print("Please make sure you have replaced 'YOUR_API_KEY' with a valid key.")
# Out:
# ✅ Gemini API configured successfully.

# %%
# --- Load Data and Set Up for Resumable Processing ---

# Define filenames
input_filename = 'fpkm_counts_with_annotations.csv'
output_filename = 'fpkm_with_metabolic_summaries.csv'

# Check if a progress file already exists
if os.path.exists(output_filename):
    print(f"🔄 Resuming from previously saved progress file: '{output_filename}'")
    df = pd.read_csv(output_filename)
else:
    print(f"🚀 Starting a new run. Loading data from: '{input_filename}'")
    try:
        df = pd.read_csv(input_filename)
        # Add the new column for the results, initialized as empty
        df['Metabolic_Summary'] = None
    except FileNotFoundError:
        print(f"🔴 ERROR: The input file '{input_filename}' was not found.")
        # Stop execution if the file doesn't exist.
        # In Jupyter, this will just prevent subsequent cells from running as intended.

# Display the status of your data
print(f"\nTotal rows in DataFrame: {len(df)}")
if 'Metabolic_Summary' in df.columns:
    rows_processed = df['Metabolic_Summary'].notna().sum()
    print(f"Rows already processed: {rows_processed}")
    print(f"Rows remaining: {len(df) - rows_processed}")
# Out:
# 🚀 Starting a new run. Loading data from: 'fpkm_counts_with_annotations.csv'
#
# Total rows in DataFrame: 6575
# Rows already processed: 0
# Rows remaining: 6575

# %%
def get_web_context(gene_identifier, kegg_info, jgi_info):
    """Searches for a gene and scrapes the text content from the top result."""
    if pd.notna(kegg_info) and 'no KO assigned' not in str(kegg_info):
        query = f"{kegg_info} metabolic pathway function"
    elif pd.notna(jgi_info):
        query = f"{gene_identifier} {jgi_info} metabolic function"
    else:
        query = f"{gene_identifier} metabolic synthesis role"
    
    try:
        # ----- THE DEFINITIVE FIX IS HERE -----
        # Removed all arguments from search() and added a manual time.sleep() after.
        # This is the most compatible method.
        print(f"  Searching for: \"{query}\"")
        search_results = search(query)
        time.sleep(2.0) # Manual delay to prevent being blocked
        
        first_url = next(search_results, None) # Get the first item, or None if empty
        # ------------------------------------
        
        if not first_url:
            return None, "Skipped (No search results found)"
        
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
        response = requests.get(first_url, headers=headers, timeout=15)
        response.raise_for_status()

        soup = BeautifulSoup(response.text, 'html.parser')
        for script_or_style in soup(["script", "style"]):
            script_or_style.decompose()
        
        return soup.get_text(separator=' ', strip=True)[:8000], None
    except Exception as e:
        return None, f"Skipped (Web scraping error: {str(e)})"

def get_summary_from_gemini(context, gene_id):
    """Queries the Gemini model for a summary."""
    prompt = f"""
    Analyze the provided text about the gene '{gene_id}' to answer the following question.

    Question: What does this gene synthesize or what metabolic pathway is it a part of?

    Based your answer only on the text below. Provide a concise, one-sentence summary. If the text does not contain information about metabolic synthesis or pathways, respond with 'No specific metabolic synthesis information found.'

    --- Text ---
    {context}
    --- End of Text ---

    Summary:
    """
    
    try:
        response = model.generate_content(prompt)
        time.sleep(1) # Short delay to respect API rate limits
        return response.text.strip()
    except Exception as e:
        return f"Skipped (Gemini API Error: {e})"

print("✅ Core functions defined.")
# Out:
# ✅ Core functions defined.

# %%
# --- Main Processing Loop ---

# Define the size of each batch
batch_size = 5

# Find the indices of rows that have not been processed yet
# We check for None, NaN, or any other empty-like value.
unprocessed_indices = df[df['Metabolic_Summary'].isna()].index

print(f"Starting processing for {len(unprocessed_indices)} remaining rows...")

for i in range(0, len(unprocessed_indices), batch_size):
    # Get the next batch of indices to process
    batch_indices = unprocessed_indices[i:i + batch_size]
    
    if len(batch_indices) == 0:
        print("No more rows to process.")
        break

    print(f"\n--- Processing Batch {i//batch_size + 1} (Rows {batch_indices[0]} to {batch_indices[-1]}) ---")
    
    for index in batch_indices:
        row = df.loc[index]
        gene_id = row['Geneid']
        
        print(f"  Processing Gene ID: {gene_id}...")
        
        # 1. Get context from the web
        context, error = get_web_context(gene_id, row.get('KEGG_annotation'), row.get('JGI_annotation'))
        
        if error:
            summary = error
        else:
            # 2. Get summary from Gemini
            summary = get_summary_from_gemini(context, gene_id)

        print(f"    -> Summary: {summary}")
        
        # 3. Add the summary to the DataFrame
        df.at[index, 'Metabolic_Summary'] = summary

    # 4. Save progress to the output file after each batch
    try:
        df.to_csv(output_filename, index=False)
        print(f"💾 Progress saved to '{output_filename}'")
    except Exception as e:
        print(f"🔴 CRITICAL: Could not save progress to file. Error: {e}")

print("\n--- ✅ All processing complete! ---")
# Out:
# Starting processing for 6575 remaining rows...
#
# --- Processing Batch 1 (Rows 0 to 4) ---
#   Processing Gene ID: jgi|Sacce1|1000|YDL018C...
#   Searching for: "jgi|Sacce1|1000|YDL018C metabolic synthesis role"
#     -> Summary: The text describes the JGI Metabolomics Program as focused on understanding the roles of small molecules (metabolites) in biological systems, linking them with genomic data to study processes like nutrient cycling, plant-microbe interactions, and environmental responses, and identifying enzymatic transformations and metabolic pathways.
#   Processing Gene ID: jgi|Sacce1|1001|YDL017W...
#   Searching for: "K02214 cell division control protein 7 [EC:2.7.11.1] | (RefSeq) CDC7, LSD6, SAS1; serine/threonine protein kinase CDC7 metabolic pathway function"
#     -> Summary: This gene encodes a cell division cycle protein with kinase activity that is critical for the G1/S transition and essential for initiation of DNA replication.
#   Processing Gene ID: jgi|Sacce1|1002|YDL016C...
#   Searching for: "jgi|Sacce1|1002|YDL016C metabolic synthesis role"
#     -> Summary: The DNA Synthesis Program synthesizes genes, pathways, and even whole chromosomes to advance functional genomics and develop biofuels, biochemicals, and biosystems for bioenergy and bioproduct applications.
#   Processing Gene ID: jgi|Sacce1|1003|YDL015C...
#   Searching for: "K10258 very-long-chain enoyl-CoA reductase [EC:1.3.1.93] | (RefSeq) TSC13; trans-2-enoyl-CoA reductase (NADPH) TSC13 metabolic pathway function"
#     -> Summary: Very-long-chain enoyl-CoA reductase catalyzes a chemical reaction involving a very-long-chain acyl-CoA and NADP+ to produce a very-long-chain trans-2,3-dehydroacyl-CoA, NADPH, and H+, and is a component of the elongase complex responsible for extending palmitoyl-CoA and stearoyl-CoA in fatty acid elongation.
#   Processing Gene ID: jgi|Sacce1|1004|YDL014W...
#   Searching for: "K14563 rRNA 2'-O-methyltransferase fibrillarin [EC:2.1.1.-] | (RefSeq) NOP1, LOT3; rRNA methyltransferase NOP1 metabolic pathway function"
#     -> Summary: No specific metabolic synthesis information found.
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 2 (Rows 5 to 9) ---
#   Processing Gene ID: jgi|Sacce1|1005|YDL013W...
#   Searching for: "K22645 E3 ubiquitin-protein ligase complex SLX5-SLX8 subunit SLX5 [EC:2.3.2.27] | (RefSeq) SLX5, HEX3, ULS2; SUMO-targeted ubiquitin ligase complex subunit SLX5 metabolic pathway function"
#     -> Summary: No specific metabolic synthesis information found.
#   Processing Gene ID: jgi|Sacce1|1006|YDL012C...
#   Searching for: "jgi|Sacce1|1006|YDL012C metabolic synthesis role"
#     -> Summary: The DNA Synthesis Program synthesizes genes, pathways, and even whole chromosomes to advance functional genomics and develop biofuels, biochemicals, and biosystems for bioenergy and bioproduct applications.
#   Processing Gene ID: jgi|Sacce1|1007|YDL011C...
#   Searching for: "jgi|Sacce1|1007|YDL011C metabolic synthesis role"
#     -> Summary: The DNA Synthesis Program synthesizes genes, pathways, and even whole chromosomes to advance functional genomics and develop biofuels, biochemicals, and other bioenergy solutions.
#   Processing Gene ID: jgi|Sacce1|1008|YDL010W...
#   Searching for: "jgi|Sacce1|1008|YDL010W metabolic synthesis role"
#     -> Summary: The text describes the JGI Metabolomics Program as focused on understanding the roles of small molecules (metabolites) in biological systems, integrating this data with genomics to study processes like nutrient cycling, plant-microbe interactions, and environmental responses, and identifying enzymatic transformations and metabolic pathways.
#   Processing Gene ID: jgi|Sacce1|1009|YDL009C...
#   Searching for: "jgi|Sacce1|1009|YDL009C metabolic synthesis role"
#     -> Summary: Skipped (Web scraping error: 403 Client Error: Forbidden for url: https://scholar.google.com/scholar?q=jgi%7CSacce1%7C1009%7CYDL009C+metabolic+synthesis+role&hl=en&as_sdt=0&as_vis=1&oi=scholart)
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 3 (Rows 10 to 14) ---
#   Processing Gene ID: jgi|Sacce1|100|YAR030C...
#   Searching for: "jgi|Sacce1|100|YAR030C metabolic synthesis role"
#     -> Summary: Skipped (Web scraping error: 403 Client Error: Forbidden for url: https://scholar.google.com/scholar?q=jgi%7CSacce1%7C100%7CYAR030C+metabolic+synthesis+role&hl=en&as_sdt=0&as_vis=1&oi=scholart)
#   Processing Gene ID: jgi|Sacce1|1010|YDL008W...
#   Searching for: "K03358 anaphase-promoting complex subunit 11 | (RefSeq) APC11; anaphase promoting complex subunit 11 metabolic pathway function"
#     -> Summary: The ANAPC11 gene synthesizes a subunit of the anaphase-promoting complex, which is involved in ubiquitin-protein transferase activity, the regulation of the mitotic metaphase/anaphase transition, and protein polyubiquitination.
#   Processing Gene ID: jgi|Sacce1|1011|YDL007C-A...
#   Searching for: "jgi|Sacce1|1011|YDL007C-A metabolic synthesis role"
#     -> Summary: The text describes the JGI Metabolomics Program as focused on understanding the roles of small molecules (metabolites) in biological systems and linking them with genomic data to study processes like nutrient cycling, plant-microbe interactions, and environmental responses, but does not specify what gene 'jgi|Sacce1|1011|YDL007C-A' synthesizes.
#   Processing Gene ID: jgi|Sacce1|1012|YDL007W...
#   Searching for: "K03062 26S proteasome regulatory subunit T2 | (RefSeq) RPT2, YHS4, YTA5; proteasome regulatory particle base subunit RPT2 metabolic pathway function"
#     -> Summary: The gene PSMC2 encodes an ATPase subunit of the 26S proteasome, a multi-protein complex involved in protein degradation and potentially in the regulation of transcription and immune responses.
#   Processing Gene ID: jgi|Sacce1|1013|YDL006W...
#   Searching for: "K19704 protein phosphatase PTC1 [EC:3.1.3.16] | (RefSeq) PTC1, CWH47, KCS2, TPD1; type 2C protein phosphatase PTC1 metabolic pathway function"
#     -> Summary: This gene encodes a protein serine/threonine phosphatase, an enzyme that removes phosphate groups from serine or threonine residues on proteins, and is part of a diverse group involved in regulating various cellular processes through dephosphorylation.
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 4 (Rows 15 to 19) ---
#   Processing Gene ID: jgi|Sacce1|1014|YDL005C...
#   Searching for: "K15154 mediator of RNA polymerase II transcription subunit 2 | (RefSeq) MED2; Med2p metabolic pathway function"
#     -> Summary: No specific metabolic synthesis information found.
#   Processing Gene ID: jgi|Sacce1|1015|YDL004W...
#   Searching for: "K02134 F-type H+-transporting ATPase subunit delta | (RefSeq) ATP16; F1F0 ATP synthase subunit delta metabolic pathway function"
#     -> Summary: This gene synthesizes a subunit (delta) of F-type H+-transporting ATPase, and is part of oxidative phosphorylation and energy metabolism pathways.
#   Processing Gene ID: jgi|Sacce1|1016|YDL003W...
#   Searching for: "K06670 cohesin complex subunit SCC1 | (RefSeq) MCD1, PDS3, RHC21, SCC1; kleisin alpha metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 34
# }
# ])
#   Processing Gene ID: jgi|Sacce1|1017|YDL002C...
#   Searching for: "K11680 non-histone protein 10 | (RefSeq) NHP10, HMO2; Nhp10p metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 31
# }
# ])
#   Processing Gene ID: jgi|Sacce1|1018|YDL001W...
#   Searching for: "jgi|Sacce1|1018|YDL001W metabolic synthesis role"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ])
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 5 (Rows 20 to 24) ---
#   Processing Gene ID: jgi|Sacce1|1019|YDR001C...
#   Searching for: "K01194 alpha,alpha-trehalase [EC:3.2.1.28] | (RefSeq) NTH1; alpha,alpha-trehalase NTH1 metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 23
# }
# ])
#   Processing Gene ID: jgi|Sacce1|101|YAR031W...
#   Searching for: "jgi|Sacce1|101|YAR031W metabolic synthesis role"
#     -> Summary: Skipped (Web scraping error: 403 Client Error: Forbidden for url: https://scholar.google.com/scholar?q=jgi%7CSacce1%7C101%7CYAR031W+metabolic+synthesis+role&hl=en&as_sdt=0&as_vis=1&oi=scholart)
#   Processing Gene ID: jgi|Sacce1|1020|YDR002W...
#   Searching for: "K15306 Ran-binding protein 1 | (RefSeq) YRB1, CST20, HTN1, SFO1, STP52; Ran GTPase-binding protein YRB1 metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 17
# }
# ])
#   Processing Gene ID: jgi|Sacce1|1021|YDR003W...
#   Searching for: "jgi|Sacce1|1021|YDR003W metabolic synthesis role"
#     -> Summary: Skipped (Web scraping error: 403 Client Error: Forbidden for url: https://scholar.google.com/scholar?q=jgi%7CSacce1%7C1021%7CYDR003W+metabolic+synthesis+role&hl=en&as_sdt=0&as_vis=1&oi=scholart)
#   Processing Gene ID: jgi|Sacce1|1022|YDR003W-A...
#   Searching for: "jgi|Sacce1|1022|YDR003W-A metabolic synthesis role"
#     -> Summary: The DNA Synthesis Program synthesizes genes, pathways, and even whole chromosomes to advance functional genomics and develop biofuels, biochemicals, and other bioenergy solutions.
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 6 (Rows 25 to 29) ---
#   Processing Gene ID: jgi|Sacce1|1023|YDR004W...
#   Searching for: "K10958 DNA repair protein RAD57 | (RefSeq) RAD57; putative DNA-dependent ATPase RAD57 metabolic pathway function"
#     -> Summary: The gene 'jgi|Sacce1|1023|YDR004W' (RAD57) is predicted to enable DNA binding and catalytic activity acting on DNA, and is involved in heteroduplex formation, meiotic DNA recombinase assembly, and telomere maintenance via recombination, functioning as part of the Rad51C-XRCC3 complex.
#   Processing Gene ID: jgi|Sacce1|1024|YDR005C...
#   Searching for: "K25817 repressor of RNA polymerase III transcription MAF1 | (RefSeq) MAF1; RNA polymerase III-inhibiting protein MAF1 metabolic pathway function"
#     -> Summary: No specific metabolic synthesis information found.
#   Processing Gene ID: jgi|Sacce1|1025|YDR006C...
#   Searching for: "jgi|Sacce1|1025|YDR006C Glucan 1,4-alpha-glucosidase metabolic function"
#     -> Summary: Skipped (Web scraping error: 400 Client Error: Bad Request for url: https://www.sciencedirect.com/unsupported_browser)
#   Processing Gene ID: jgi|Sacce1|1026|YDR007W...
#   Searching for: "K01817 phosphoribosylanthranilate isomerase [EC:5.3.1.24] | (RefSeq) TRP1; phosphoribosylanthranilate isomerase TRP1 metabolic pathway function"
#     -> Summary: The gene 'jgi|Sacce1|1026|YDR007W' encodes phosphoribosylanthranilate isomerase, an enzyme involved in the biosynthesis of tryptophan.
#   Processing Gene ID: jgi|Sacce1|1027|YDR008C...
#   Searching for: "jgi|Sacce1|1027|YDR008C metabolic synthesis role"
#     -> Summary: The DNA Synthesis Program synthesizes genes, pathways, and even whole chromosomes to advance functional genomics and develop biofuels, biochemicals, and other bioenergy solutions, with a focus on areas like lignocellulose decomposition, CO2 fixation, and plant metabolite biosynthesis.
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 7 (Rows 30 to 34) ---
#   Processing Gene ID: jgi|Sacce1|1028|YDR009W...
#   Searching for: "K00849 galactokinase [EC:2.7.1.6] | (RefSeq) GAL3; transcriptional regulator GAL3 metabolic pathway function"
#     -> Summary: The gene 'jgi|Sacce1|1028|YDR009W' encodes galactokinase, an enzyme that phosphorylates alpha-D-galactose as part of the Leloir pathway for galactose metabolism.
#   Processing Gene ID: jgi|Sacce1|1029|YDR010C...
#   Searching for: "jgi|Sacce1|1029|YDR010C metabolic synthesis role"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ])
#   Processing Gene ID: jgi|Sacce1|102|YAR033W...
#   Searching for: "jgi|Sacce1|102|YAR033W metabolic synthesis role"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 21
# }
# ])
#   Processing Gene ID: jgi|Sacce1|1030|YDR011W...
#   Searching for: "K08712 ATP-binding cassette, subfamily G (WHITE), member 2, SNQ2 | (RefSeq) SNQ2; ATP-binding cassette transporter SNQ2 metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 16
# }
# ])
#   Processing Gene ID: jgi|Sacce1|1031|YDR012W...
#   Searching for: "K02930 large subunit ribosomal protein L4e | (RefSeq) RPL4B; ribosomal 60S subunit protein L4B metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 12
# }
# ])
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 8 (Rows 35 to 39) ---
#   Processing Gene ID: jgi|Sacce1|1032|YDR013W...
#   Searching for: "K10732 GINS complex subunit 1 | (RefSeq) PSF1, CDC101; DNA replication protein PSF1 metabolic pathway function"
#     -> Summary: No specific metabolic synthesis information found.
#   Processing Gene ID: jgi|Sacce1|1033|YDR014W...
#   Searching for: "jgi|Sacce1|1033|YDR014W metabolic synthesis role"
#     -> Summary: Skipped (Web scraping error: 403 Client Error: Forbidden for url: https://scholar.google.com/scholar?q=jgi%7CSacce1%7C1033%7CYDR014W+metabolic+synthesis+role&hl=en&as_sdt=0&as_vis=1&oi=scholart)
#   Processing Gene ID: jgi|Sacce1|1034|YDR014W-A...
#   Searching for: "jgi|Sacce1|1034|YDR014W-A metabolic synthesis role"
#     -> Summary: The DNA Synthesis Program synthesizes genes, pathways, and even whole chromosomes to advance functional genomics and contribute to the development of biofuels, biochemicals, and biosystems for bioenergy applications.
#   Processing Gene ID: jgi|Sacce1|1035|YDR015C...
#   Searching for: "jgi|Sacce1|1035|YDR015C metabolic synthesis role"
#     -> Summary: The text describes the JGI Metabolomics Program as focused on understanding the roles of small molecules (metabolites) in biological systems, linking them with genomic data to study processes like nutrient cycling, plant-microbe interactions, and environmental responses, and identifying enzymatic transformations and metabolic pathways.
#   Processing Gene ID: jgi|Sacce1|1036|YDR016C...
#   Searching for: "K11553 DASH complex subunit DAD1 | (RefSeq) DAD1; Dad1p metabolic pathway function"
#     -> Summary: No specific metabolic synthesis information found.
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 9 (Rows 40 to 44) ---
#   Processing Gene ID: jgi|Sacce1|1037|YDR017C...
#   Searching for: "K07756 inositol-hexakisphosphate 5-kinase [EC:2.7.4.21] | (RefSeq) KCS1; inositol polyphosphate kinase KCS1 metabolic pathway function"
#     -> Summary: Inositol-hexakisphosphate kinase (EC 2.7.4.21) catalyzes the phosphorylation of 1D-myo-inositol hexakisphosphate (phytic acid) to produce 1D-myo-inositol 5-diphosphate 1,2,3,4,6-pentakisphosphate and other related inositol polyphosphates, participating in inositol phosphate metabolism.
#   Processing Gene ID: jgi|Sacce1|1038|YDR018C...
#   Searching for: "jgi|Sacce1|1038|YDR018C Glycerol-3-phosphate O-acyltransferase metabolic function"
#     -> Summary: Glycerol-3-phosphate acyltransferases (GPATs) catalyze the first step in the synthesis of triacylglycerol (TAG) and glycerophospholipids by converting glycerol-3-phosphate and acyl-CoA to lysophosphatidic acid, playing a key role in lipid metabolism and insulin resistance.
#   Processing Gene ID: jgi|Sacce1|1039|YDR019C...
#   Searching for: "K00605 glycine cleavage system T protein (aminomethyltransferase) [EC:2.1.2.10] | (RefSeq) GCV1, GSD1; glycine decarboxylase subunit T metabolic pathway function"
#     -> Summary: The gene 'jgi|Sacce1|1039|YDR019C' encodes an aminomethyltransferase, a component of the glycine cleavage system involved in glycine metabolism and one-carbon group transfer.
#   Processing Gene ID: jgi|Sacce1|103|YAR035W...
#   Searching for: "K00624 carnitine O-acetyltransferase [EC:2.3.1.7] | (RefSeq) YAT1; carnitine O-acetyltransferase YAT1 metabolic pathway function"
#     -> Summary: This gene synthesizes Carnitine O-acetyltransferase, an enzyme identified by EC 2.3.1.7.
#   Processing Gene ID: jgi|Sacce1|1040|YDR020C...
#   Searching for: "K00876 uridine kinase [EC:2.7.1.48] | (RefSeq) DAS2, RRT3; putative uridine kinase DAS2 metabolic pathway function"
#     -> Summary: This gene synthesizes uridine monophosphate (UMP) and cytidine monophosphate (CMP) from uridine and cytidine, respectively, and is part of pyrimidine metabolism and drug metabolism pathways.
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 10 (Rows 45 to 49) ---
#   Processing Gene ID: jgi|Sacce1|1041|YDR021W...
#   Searching for: "K13025 ATP-dependent RNA helicase [EC:5.6.2.7] | (RefSeq) FAL1; ATP-dependent RNA helicase FAL1 metabolic pathway function"
#     -> Summary: This gene is involved in ribosome biogenesis, mRNA surveillance, nucleocytoplasmic transport, aminoacyl-tRNA biosynthesis, and potentially protein folding, sorting, and degradation, as indicated by its association with multiple KEGG pathways related to these processes.
#   Processing Gene ID: jgi|Sacce1|1042|YDR022C...
#   Searching for: "K21144 autophagy-related protein 31 | (RefSeq) ATG31, CIS1; Atg31p metabolic pathway function"
#     -> Summary: The gene 'jgi|Sacce1|1042|YDR022C' (Cis1/Atg31) is required for autophagosome formation and functions in concert with Atg17 as part of a complex involved in autophagy.
#   Processing Gene ID: jgi|Sacce1|1043|YDR023W...
#   Searching for: "K01875 seryl-tRNA synthetase [EC:6.1.1.11] | (RefSeq) SES1; serine--tRNA ligase SES1 metabolic pathway function"
#     -> Summary: The gene 'jgi|Sacce1|1043|YDR023W' synthesizes L-seryl-tRNA, and is part of the aminoacyl-tRNA biosynthesis pathway.
#   Processing Gene ID: jgi|Sacce1|1044|YDR024W...
#   Searching for: "jgi|Sacce1|1044|YDR024W metabolic synthesis role"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ])
#   Processing Gene ID: jgi|Sacce1|1045|YDR025W...
#   Searching for: "K02949 small subunit ribosomal protein S11e | (RefSeq) RPS11A; ribosomal 40S subunit protein S11A metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ])
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 11 (Rows 50 to 54) ---
#   Processing Gene ID: jgi|Sacce1|1046|YDR026C...
#   Searching for: "K09424 Myb-like DNA-binding protein REB1 | (RefSeq) NSI1, YTT1; Nsi1p metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 33
# }
# ])
#   Processing Gene ID: jgi|Sacce1|1047|YDR027C...
#   Searching for: "K17600 vacuolar protein sorting-associated protein 54 | (RefSeq) VPS54, CGP1, LUV1, TCS3; Vps54p metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ])
#   Processing Gene ID: jgi|Sacce1|1048|YDR028C...
#   Searching for: "jgi|Sacce1|1048|YDR028C Adenosinetriphosphatase metabolic function"
#     -> Summary: Skipped (Web scraping error: 403 Client Error: Forbidden for url: https://www.metabolismjournal.com/article/0026-0495(95)90238-4/fulltext)
#   Processing Gene ID: jgi|Sacce1|1049|YDR029W...
#   Searching for: "jgi|Sacce1|1049|YDR029W metabolic synthesis role"
#     -> Summary: Skipped (Web scraping error: 403 Client Error: Forbidden for url: https://scholar.google.com/scholar?q=jgi%7CSacce1%7C1049%7CYDR029W+metabolic+synthesis+role&hl=en&as_sdt=0&as_vis=1&oi=scholart)
#   Processing Gene ID: jgi|Sacce1|104|YAR035C-A...
#   Searching for: "jgi|Sacce1|104|YAR035C-A metabolic synthesis role"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 21
# }
# ])
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 12 (Rows 55 to 59) ---
#   Processing Gene ID: jgi|Sacce1|1050|YDR030C...
#   Searching for: "K10570 DNA excision repair protein ERCC-8 | (RefSeq) RAD28; Rad28p metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 18
# }
# ])
#   Processing Gene ID: jgi|Sacce1|1051|YDR031W...
#   Searching for: "jgi|Sacce1|1051|YDR031W metabolic synthesis role"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 15
# }
# ])
#   Processing Gene ID: jgi|Sacce1|1052|YDR032C...
#   Searching for: "K03809 NAD(P)H dehydrogenase (quinone) [EC:1.6.5.2] | (RefSeq) PST2; flavodoxin-like fold family protein metabolic pathway function"
#     -> Summary: The gene 'jgi|Sacce1|1052|YDR032C' encodes NAD(P)H dehydrogenase (quinone) and is involved in ubiquinone and other terpenoid-quinone biosynthesis, as well as broader metabolic pathways and cofactor metabolism.
#   Processing Gene ID: jgi|Sacce1|1053|YDR033W...
#   Searching for: "jgi|Sacce1|1053|YDR033W metabolic synthesis role"
#     -> Summary: The DNA Synthesis Program synthesizes genes, pathways, and even whole chromosomes to advance functional genomics and develop biofuels, biochemicals, and other bioenergy solutions, with a focus on areas like lignocellulose decomposition, CO2 fixation, and plant metabolite biosynthesis.
#   Processing Gene ID: jgi|Sacce1|1054|YDR034C...
#   Searching for: "jgi|Sacce1|1054|YDR034C metabolic synthesis role"
#     -> Summary: The text describes the JGI Metabolomics Program as focused on understanding the roles of small molecules (metabolites) in biological systems, integrating this data with genomics to study processes like nutrient cycling, plant-microbe interactions, and environmental responses, and identifying enzymatic transformations and metabolic pathways.
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 13 (Rows 60 to 64) ---
#   Processing Gene ID: jgi|Sacce1|1055|YDR034C-A...
#   Searching for: "jgi|Sacce1|1055|YDR034C-A metabolic synthesis role"
#     -> Summary: The text describes the JGI Metabolomics Program as focused on understanding the roles of small molecules (metabolites) in biological systems, integrating this data with genomics to study processes like nutrient cycling, plant-microbe interactions, and environmental responses, and identifying enzymatic transformations and metabolic pathways.
#   Processing Gene ID: jgi|Sacce1|1056|YDR034W-B...
#   Searching for: "jgi|Sacce1|1056|YDR034W-B metabolic synthesis role"
#     -> Summary: Skipped (Web scraping error: 403 Client Error: Forbidden for url: https://scholar.google.com/scholar?q=jgi%7CSacce1%7C1056%7CYDR034W-B+metabolic+synthesis+role&hl=en&as_sdt=0&as_vis=1&oi=scholart)
#   Processing Gene ID: jgi|Sacce1|1057|YDR035W...
#   Searching for: "K01626 3-deoxy-7-phosphoheptulonate synthase [EC:2.5.1.54] | (RefSeq) ARO3; 3-deoxy-7-phosphoheptulonate synthase ARO3 metabolic pathway function"
#     -> Summary: The gene 'jgi|Sacce1|1057|YDR035W' encodes 3-deoxy-7-phosphoheptulonate synthase and is part of the phenylalanine, tyrosine, and tryptophan biosynthesis pathway, specifically the shikimate pathway.
#   Processing Gene ID: jgi|Sacce1|1058|YDR036C...
#   Searching for: "K05605 3-hydroxyisobutyryl-CoA hydrolase [EC:3.1.2.4] | (RefSeq) EHD3, mS47; mitochondrial 37S ribosomal protein EHD3 metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ])
#   Processing Gene ID: jgi|Sacce1|1059|YDR037W...
#   Searching for: "K04567 lysyl-tRNA synthetase, class II [EC:6.1.1.6] | (RefSeq) KRS1, GCD5; lysine--tRNA ligase KRS1 metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 14
# }
# ])
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 14 (Rows 65 to 69) ---
#   Processing Gene ID: jgi|Sacce1|105|YAR042W...
#   Searching for: "K20456 oxysterol-binding protein 1 | (RefSeq) SWH1, OSH1, YAR044W; oxysterol-binding protein related protein SWH1 metabolic pathway function"
#     -> Summary: Oxysterol-binding protein-1 (OSBP1) regulates the processing and trafficking of the amyloid precursor protein (APP) and is involved in linking cholesterol metabolism with intracellular APP trafficking and Aβ production.
#   Processing Gene ID: jgi|Sacce1|1060|YDR038C...
#   Searching for: "K01536 P-type Na+/K+ transporter [EC:7.2.2.3 7.2.2.-] | (RefSeq) ENA5; putative Na(+)-exporting P-type ATPase ENA5 metabolic pathway function"
#     -> Summary: Skipped (Web scraping error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')))
#   Processing Gene ID: jgi|Sacce1|1061|YDR039C...
#   Searching for: "K01536 P-type Na+/K+ transporter [EC:7.2.2.3 7.2.2.-] | (RefSeq) ENA2; Na(+)-exporting P-type ATPase ENA2 metabolic pathway function"
#     -> Summary: Skipped (Web scraping error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')))
#   Processing Gene ID: jgi|Sacce1|1062|YDR040C...
#   Searching for: "K01536 P-type Na+/K+ transporter [EC:7.2.2.3 7.2.2.-] | (RefSeq) ENA1, HOR6, PMR2; Na(+)/Li(+)-exporting P-type ATPase ENA1 metabolic pathway function"
#     -> Summary: Skipped (No search results found)
#   Processing Gene ID: jgi|Sacce1|1063|YDR041W...
#   Searching for: "K02946 small subunit ribosomal protein S10 | (RefSeq) RSM10, uS10m; mitochondrial 37S ribosomal protein RSM10 metabolic pathway function"
#     -> Summary: No specific metabolic synthesis information found.
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 15 (Rows 70 to 74) ---
#   Processing Gene ID: jgi|Sacce1|1064|YDR042C...
#   Searching for: "jgi|Sacce1|1064|YDR042C metabolic synthesis role"
#     -> Summary: The text describes the JGI Metabolomics Program as focused on understanding the roles of small molecules (metabolites) in biological systems, linking them with genomic data to study processes like nutrient cycling, plant-microbe interactions, and environmental responses, and identifying enzymatic transformations and metabolic pathways.
#   Processing Gene ID: jgi|Sacce1|1065|YDR043C...
#   Searching for: "jgi|Sacce1|1065|YDR043C metabolic synthesis role"
#     -> Summary: The text describes the JGI Metabolomics Program as focused on understanding the roles of small molecules (metabolites) in biological systems, integrating this data with genomics to study processes like nutrient cycling, plant-microbe interactions, and environmental responses, and identifying enzymatic transformations and metabolic pathways.
#   Processing Gene ID: jgi|Sacce1|1066|YDR044W...
#   Searching for: "K00228 coproporphyrinogen III oxidase [EC:1.3.3.3] | (RefSeq) HEM13; coproporphyrinogen oxidase metabolic pathway function"
#     -> Summary: The gene 'jgi|Sacce1|1066|YDR044W' synthesizes coproporphyrinogen oxidase, an enzyme involved in porphyrin metabolism that converts coproporphyrinogen III to protoporphyrinogen-IX.
#   Processing Gene ID: jgi|Sacce1|1067|YDR045C...
#   Searching for: "K03019 DNA-directed RNA polymerase III subunit RPC11 | (RefSeq) RPC11; DNA-directed RNA polymerase III core subunit RPC11 metabolic pathway function"
#     -> Summary: This gene, RPC11, contributes to DNA-directed RNA polymerase activity, specifically being involved in tRNA transcription and termination of transcription by RNA polymerase III, and is part of the RNA polymerase III complex.
#   Processing Gene ID: jgi|Sacce1|1068|YDR046C...
#   Searching for: "K16261 yeast amino acid transporter | (RefSeq) BAP3, PAP1; amino acid transporter BAP3 metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 17
# }
# ])
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 16 (Rows 75 to 79) ---
#   Processing Gene ID: jgi|Sacce1|1069|YDR047W...
#   Searching for: "K01599 uroporphyrinogen decarboxylase [EC:4.1.1.37] | (RefSeq) HEM12, HEM6; uroporphyrinogen decarboxylase HEM12 metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 15
# }
# ])
#   Processing Gene ID: jgi|Sacce1|106|YAR047C...
#   Searching for: "jgi|Sacce1|106|YAR047C metabolic synthesis role"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 12
# }
# ])
#   Processing Gene ID: jgi|Sacce1|1070|YDR048C...
#   Searching for: "jgi|Sacce1|1070|YDR048C metabolic synthesis role"
#     -> Summary: The text describes the JGI Metabolomics Program as focused on understanding the roles of small molecules (metabolites) in biological systems, linking them with genomic data to study nutrient cycling, plant-microbe interactions, and environmental responses, and identifying enzymatic transformations and metabolic pathways.
#   Processing Gene ID: jgi|Sacce1|1071|YDR049W...
#   Searching for: "K26089 ankyrin repeat and zinc finger domain-containing protein 1 | (RefSeq) VMS1; Vms1p metabolic pathway function"
#     -> Summary: The gene 'ANKZF1' plays an indispensable role in the mitochondrial response to cellular stress, impacting mitochondrial integrity and respiration when cells are stressed.
#   Processing Gene ID: jgi|Sacce1|1072|YDR050C...
#   Searching for: "K01803 triosephosphate isomerase (TIM) [EC:5.3.1.1] | (RefSeq) TPI1; triose-phosphate isomerase TPI1 metabolic pathway function"
#     -> Summary: The gene 'jgi|Sacce1|1072|YDR050C' encodes triosephosphate isomerase (TIM), an enzyme involved in glycolysis, gluconeogenesis, fructose and mannose metabolism, the Calvin cycle, and several other carbon and amino acid metabolic pathways.
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 17 (Rows 80 to 84) ---
#   Processing Gene ID: jgi|Sacce1|1073|YDR051C...
#   Searching for: "jgi|Sacce1|1073|YDR051C metabolic synthesis role"
#     -> Summary: The text describes the JGI Metabolomics Program as focused on understanding the roles of small molecules (metabolites) in biological systems, integrating this data with genomics to study processes like nutrient cycling, plant-microbe interactions, and environmental responses, and identifying enzymatic transformations and metabolic pathways.
#   Processing Gene ID: jgi|Sacce1|1074|YDR052C...
#   Searching for: "K02309 regulatory subunit for Cdc7p protein kinase | (RefSeq) DBF4, DNA52, LSD7; protein serine/threonine kinase activating protein DBF4 metabolic pathway function"
#     -> Summary: The gene 'jgi|Sacce1|1074|YDR052C' (DBF4) is involved in DNA replication, protein phosphorylation, and cell cycle regulation, functioning as an activating protein for the DBF4 protein serine/threonine kinase and as part of the Dbf4-dependent protein kinase complex.
#   Processing Gene ID: jgi|Sacce1|1075|YDR053W...
#   Searching for: "jgi|Sacce1|1075|YDR053W metabolic synthesis role"
#     -> Summary: The DNA Synthesis Program synthesizes genes, pathways, and even whole chromosomes to advance functional genomics and develop biofuels, biochemicals, and other bioenergy solutions, with a focus on areas like lignocellulose decomposition, CO2 fixation, and plant metabolite biosynthesis.
#   Processing Gene ID: jgi|Sacce1|1076|YDR054C...
#   Searching for: "K02207 ubiquitin-conjugating enzyme E2 R [EC:2.3.2.23] | (RefSeq) CDC34, DNA6, UBC3; SCF E2 ubiquitin-protein ligase catalytic subunit CDC34 metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 19
# }
# ])
#   Processing Gene ID: jgi|Sacce1|1077|YDR055W...
#   Searching for: "jgi|Sacce1|1077|YDR055W metabolic synthesis role"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 16
# }
# ])
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 18 (Rows 85 to 89) ---
#   Processing Gene ID: jgi|Sacce1|1078|YDR056C...
#   Searching for: "jgi|Sacce1|1078|YDR056C metabolic synthesis role"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 14
# }
# ])
#   Processing Gene ID: jgi|Sacce1|1079|YDR057W...
#   Searching for: "K10088 protein OS-9 | (RefSeq) YOS9; Yos9p metabolic pathway function"
#     -> Summary: The gene 'jgi|Sacce1|1079|YDR057W' (Yos9) is a component of the HMG-CoA reductase degradation (HRD) ubiquitin-ligase complex involved in the ER-associated protein degradation pathway, where it recognizes specific oligosaccharide modifications on misfolded proteins to target them for degradation.
#   Processing Gene ID: jgi|Sacce1|107|YAR050W...
#   Searching for: "jgi|Sacce1|107|YAR050W Glucan 1,4-alpha-glucosidase metabolic function"
#     -> Summary: No specific metabolic synthesis information found.
#   Processing Gene ID: jgi|Sacce1|1080|YDR058C...
#   Searching for: "K01046 triacylglycerol lipase [EC:3.1.1.3] | (RefSeq) TGL2; triglyceride lipase metabolic pathway function"
#     -> Summary: This gene synthesizes triacylglycerol lipase, an enzyme that breaks down triacylglycerols.
#   Processing Gene ID: jgi|Sacce1|1081|YDR059C...
#   Searching for: "K06689 ubiquitin-conjugating enzyme E2 D [EC:2.3.2.23] | (RefSeq) UBC5; E2 ubiquitin-conjugating protein UBC5 metabolic pathway function"
#     -> Summary: The gene 'jgi|Sacce1|1081|YDR059C' encodes a ubiquitin-conjugating enzyme E2 D and is part of pathways including Polycomb repressive complex, MAPK signaling, ubiquitin mediated proteolysis, and Toll and Imd signaling.
# ...
#   Searching for: "K23503 sideroflexin-5 | (RefSeq) FSF1; Fsf1p metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 20
# }
# ])
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 1096 (Rows 5475 to 5479) ---
#   Processing Gene ID: jgi|Sacce1|592|YCL052C...
#   Searching for: "K07541 GPI mannosyltransferase 1 subunit X | (RefSeq) PBN1; Pbn1p metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 18
# }
# ])
#   Processing Gene ID: jgi|Sacce1|5930|YOR272W...
#   Searching for: "K14863 ribosome biogenesis protein | (RefSeq) YTM1, CST14; Ytm1p metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 15
# }
# ])
#   Processing Gene ID: jgi|Sacce1|5931|YOR273C...
#   Searching for: "K28028 MFS transporter, DHA1 family, putrescine transporter | (RefSeq) TPO4; Tpo4p metabolic pathway function"
#     -> Summary: No specific metabolic synthesis information found.
#   Processing Gene ID: jgi|Sacce1|5932|YOR274W...
#   Searching for: "K00791 tRNA dimethylallyltransferase [EC:2.5.1.75] | (RefSeq) MOD5; tRNA dimethylallyltransferase metabolic pathway function"
#     -> Summary: The gene 'jgi|Sacce1|5932|YOR274W' synthesizes tRNA dimethylallyltransferase, an enzyme involved in tRNA modification and the metabolism of terpenoids and polyketides, specifically within zeatin biosynthesis and prenyltransferase pathways.
#   Processing Gene ID: jgi|Sacce1|5933|YOR275C...
#   Searching for: "K12200 programmed cell death 6-interacting protein | (RefSeq) RIM20; Rim20p metabolic pathway function"
#     -> Summary: This gene encodes a protein that functions within the ESCRT pathway in cytokinesis, endosomal vesicle formation, and enveloped virus budding, and is involved in regulating apoptosis and membrane shape during endocytosis.
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 1097 (Rows 5480 to 5484) ---
#   Processing Gene ID: jgi|Sacce1|5934|YOR276W...
#   Searching for: "K03261 cap-associated protein CAF20 | (RefSeq) CAF20, CAF2, CAP20; Caf20p metabolic pathway function"
#     -> Summary: No specific metabolic synthesis information found.
#   Processing Gene ID: jgi|Sacce1|5935|YOR277C...
#   Searching for: "jgi|Sacce1|5935|YOR277C metabolic synthesis role"
#     -> Summary: The DNA Synthesis Program synthesizes genes, pathways, and even whole chromosomes to advance functional genomics and develop biofuels, biochemicals, and other bioenergy solutions, with a focus on areas like lignocellulose decomposition, CO2 fixation, and plant metabolite biosynthesis.
#   Processing Gene ID: jgi|Sacce1|5936|YOR278W...
#   Searching for: "K01719 uroporphyrinogen-III synthase [EC:4.2.1.75] | (RefSeq) HEM4, SLU2; uroporphyrinogen-III synthase HEM4 metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 25
# }
# ])
#   Processing Gene ID: jgi|Sacce1|5937|YOR279C...
#   Searching for: "jgi|Sacce1|5937|YOR279C metabolic synthesis role"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 22
# }
# ])
#   Processing Gene ID: jgi|Sacce1|5938|YOR280C...
#   Searching for: "jgi|Sacce1|5938|YOR280C Dihydrofolate reductase metabolic function"
#     -> Summary: Skipped (Web scraping error: 403 Client Error: Forbidden for url: https://scholar.google.com/scholar?q=jgi%7CSacce1%7C5938%7CYOR280C+Dihydrofolate+reductase+metabolic+function&hl=en&as_sdt=0&as_vis=1&oi=scholart)
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 1098 (Rows 5485 to 5489) ---
#   Processing Gene ID: jgi|Sacce1|5939|YOR281C...
#   Searching for: "K28206 phosducin-like protein | (RefSeq) PLP2; Plp2p metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 16
# }
# ])
#   Processing Gene ID: jgi|Sacce1|593|YCL051W...
#   Searching for: "jgi|Sacce1|593|YCL051W metabolic synthesis role"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 14
# }
# ])
#   Processing Gene ID: jgi|Sacce1|5940|YOR282W...
#   Searching for: "jgi|Sacce1|5940|YOR282W metabolic synthesis role"
#     -> Summary: The JGI Metabolomics Platform identifies and analyzes metabolites—including primary, secondary, and lipid metabolites—to enable functional genome annotation, understand biological systems, study nutrient cycling, and discover new molecules and pathways, utilizing techniques like LC-MS and stable isotope probing.
#   Processing Gene ID: jgi|Sacce1|5941|YOR283W...
#   Searching for: "jgi|Sacce1|5941|YOR283W Phosphoglycerate mutase metabolic function"
#     -> Summary: No specific metabolic synthesis information found.
#   Processing Gene ID: jgi|Sacce1|5942|YOR284W...
#   Searching for: "jgi|Sacce1|5942|YOR284W metabolic synthesis role"
#     -> Summary: The text describes the JGI Metabolomics Program as focused on understanding the roles of small molecules (metabolites) in biological systems, integrating this data with genomics to explore processes like nutrient cycling, plant-microbe interactions, and environmental responses, and identifying enzymatic transformations and metabolic pathways.
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 1099 (Rows 5490 to 5494) ---
#   Processing Gene ID: jgi|Sacce1|5943|YOR285W...
#   Searching for: "jgi|Sacce1|5943|YOR285W metabolic synthesis role"
#     -> Summary: The text describes the JGI Metabolomics Program as focused on understanding the roles of small molecules (metabolites) in biological systems, integrating this data with genomics to explore processes like nutrient cycling, plant-microbe interactions, and environmental responses, and identifying enzymatic transformations and metabolic pathways.
#   Processing Gene ID: jgi|Sacce1|5944|YOR286W...
#   Searching for: "jgi|Sacce1|5944|YOR286W metabolic synthesis role"
#     -> Summary: The DNA Synthesis Program synthesizes genes, pathways, and even whole chromosomes to advance functional genomics and develop biofuels, biochemicals, and other bioenergy solutions.
#   Processing Gene ID: jgi|Sacce1|5945|YOR287C...
#   Searching for: "K14795 ribosomal RNA-processing protein 36 | (RefSeq) RRP36; rRNA-processing protein RRP36 metabolic pathway function"
#     -> Summary: Skipped (Web scraping error: 403 Client Error: Forbidden for url: https://www.genecards.org/cgi-bin/carddisp.pl?gene=RRP36)
#   Processing Gene ID: jgi|Sacce1|5946|YOR288C...
#   Searching for: "K09584 protein disulfide-isomerase A6 [EC:5.3.4.1] | (RefSeq) MPD1; protein disulfide isomerase MPD1 metabolic pathway function"
#     -> Summary: This gene synthesizes protein disulfide-isomerase, an enzyme that catalyzes the rearrangement of -S-S- bonds in proteins and is involved in thiol:disulfide interchange.
#   Processing Gene ID: jgi|Sacce1|5947|YOR289W...
#   Searching for: "K24611 AMME syndrome candidate gene 1 protein | (RefSeq) uncharacterized protein metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 32
# }
# ])
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 1100 (Rows 5495 to 5499) ---
#   Processing Gene ID: jgi|Sacce1|5948|YOR290C...
#   Searching for: "K11786 ATP-dependent helicase STH1/SNF2 [EC:5.6.2.-] | (RefSeq) SNF2, GAM1, HAF1, SWI2, TYE3; SWI/SNF catalytic subunit SNF2 metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ])
#   Processing Gene ID: jgi|Sacce1|5949|YOR291W...
#   Searching for: "K13526 cation-transporting P-type ATPase 13A2 [EC:7.2.2.-] | (RefSeq) YPK9; putative acid anhydride hydrolase metabolic pathway function"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 22
# }
# ])
#   Processing Gene ID: jgi|Sacce1|594|YCL050C...
#   Searching for: "K00988 sulfate adenylyltransferase (ADP) / ATP adenylyltransferase [EC:2.7.7.5 2.7.7.53] | (RefSeq) APA1, DTP1; bifunctional AP-4-A phosphorylase/ADP sulfurylase metabolic pathway function"
#     -> Summary: Skipped (No search results found)
#   Processing Gene ID: jgi|Sacce1|5950|YOR292C...
#   Searching for: "jgi|Sacce1|5950|YOR292C metabolic synthesis role"
#     -> Summary: Skipped (Gemini API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemma-3-27b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 17
# }
# ])
#   Processing Gene ID: jgi|Sacce1|5951|YOR293W...
#   Searching for: "K02947 small subunit ribosomal protein S10e | (RefSeq) RPS10A; ribosomal 40S subunit protein S10A metabolic pathway function"
#     -> Summary: No specific metabolic synthesis information found.
# 💾 Progress saved to 'fpkm_with_metabolic_summaries.csv'
#
# --- Processing Batch 1101 (Rows 5500 to 5504) ---
#   Processing Gene ID: jgi|Sacce1|5952|YOR293C-A...
#   Searching for: "jgi|Sacce1|5952|YOR293C-A metabolic synthesis role"
#     -> Summary: The DNA Synthesis Program synthesizes genes, pathways, and even whole chromosomes to advance functional genomics and develop biofuels, biochemicals, and other bioenergy solutions.
#   Processing Gene ID: jgi|Sacce1|5953|YOR294W...
#   Searching for: "K14852 regulator of ribosome biosynthesis | (RefSeq) RRS1; Rrs1p metabolic pathway function"
