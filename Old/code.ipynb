# %%
# !pip install cobra
# !pip install matplotlib
# !pip install matplotlib-venn
# !pip install seaborn
# !pip install ipympl
# !pip install upsetplot
# !pip install pillow
# Out:
# Requirement already satisfied: cobra in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.29.1)
# Requirement already satisfied: appdirs~=1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from cobra) (1.4.4)
# Requirement already satisfied: depinfo~=2.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from cobra) (2.2.0)
# Requirement already satisfied: diskcache~=5.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from cobra) (5.6.3)
# Requirement already satisfied: future in /usr/local/python/3.12.1/lib/python3.12/site-packages (from cobra) (1.0.0)
# Requirement already satisfied: httpx~=0.24 in /home/codespace/.local/lib/python3.12/site-packages (from cobra) (0.28.1)
# Requirement already satisfied: importlib-resources in /usr/local/python/3.12.1/lib/python3.12/site-packages (from cobra) (6.5.2)
# Requirement already satisfied: numpy>=1.13 in /home/codespace/.local/lib/python3.12/site-packages (from cobra) (2.3.1)
# Requirement already satisfied: optlang~=1.8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from cobra) (1.8.3)
# Requirement already satisfied: pandas<3.0,>=1.0 in /home/codespace/.local/lib/python3.12/site-packages (from cobra) (2.3.1)
# Requirement already satisfied: pydantic>=1.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from cobra) (2.11.7)
# Requirement already satisfied: python-libsbml~=5.19 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from cobra) (5.20.5)
# Requirement already satisfied: rich>=8.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from cobra) (14.1.0)
# Requirement already satisfied: ruamel.yaml~=0.16 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from cobra) (0.18.14)
# Requirement already satisfied: swiglpk in /usr/local/python/3.12.1/lib/python3.12/site-packages (from cobra) (5.0.12)
# Requirement already satisfied: anyio in /home/codespace/.local/lib/python3.12/site-packages (from httpx~=0.24->cobra) (4.9.0)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx~=0.24->cobra) (2025.7.9)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx~=0.24->cobra) (1.0.9)
# Requirement already satisfied: idna in /home/codespace/.local/lib/python3.12/site-packages (from httpx~=0.24->cobra) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx~=0.24->cobra) (0.16.0)
# Requirement already satisfied: sympy>=1.12.0 in /home/codespace/.local/lib/python3.12/site-packages (from optlang~=1.8->cobra) (1.13.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas<3.0,>=1.0->cobra) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas<3.0,>=1.0->cobra) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas<3.0,>=1.0->cobra) (2025.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ruamel.yaml~=0.16->cobra) (0.2.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=1.6->cobra) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=1.6->cobra) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/codespace/.local/lib/python3.12/site-packages (from pydantic>=1.6->cobra) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=1.6->cobra) (0.4.1)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->cobra) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from rich>=8.0->cobra) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.12/site-packages (from rich>=8.0->cobra) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=8.0->cobra) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from sympy>=1.12.0->optlang~=1.8->cobra) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /home/codespace/.local/lib/python3.12/site-packages (from anyio->httpx~=0.24->cobra) (1.3.1)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in /home/codespace/.local/lib/python3.12/site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Requirement already satisfied: matplotlib-venn in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.1.2)
# Requirement already satisfied: matplotlib in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib-venn) (3.10.3)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib-venn) (2.3.1)
# Requirement already satisfied: scipy in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib-venn) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (25.0)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Requirement already satisfied: seaborn in /home/codespace/.local/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/codespace/.local/lib/python3.12/site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: pandas>=1.2 in /home/codespace/.local/lib/python3.12/site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/codespace/.local/lib/python3.12/site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Requirement already satisfied: ipympl in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.9.7)
# Requirement already satisfied: ipython<10 in /home/codespace/.local/lib/python3.12/site-packages (from ipympl) (9.4.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ipympl) (8.1.7)
# Requirement already satisfied: matplotlib<4,>=3.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from ipympl) (3.10.3)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.12/site-packages (from ipympl) (2.3.1)
# Requirement already satisfied: pillow in /home/codespace/.local/lib/python3.12/site-packages (from ipympl) (11.3.0)
# Requirement already satisfied: traitlets<6 in /home/codespace/.local/lib/python3.12/site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: decorator in /home/codespace/.local/lib/python3.12/site-packages (from ipython<10->ipympl) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/codespace/.local/lib/python3.12/site-packages (from ipython<10->ipympl) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/codespace/.local/lib/python3.12/site-packages (from ipython<10->ipympl) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/codespace/.local/lib/python3.12/site-packages (from ipython<10->ipympl) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/codespace/.local/lib/python3.12/site-packages (from ipython<10->ipympl) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/codespace/.local/lib/python3.12/site-packages (from ipython<10->ipympl) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /home/codespace/.local/lib/python3.12/site-packages (from ipython<10->ipympl) (2.19.2)
# Requirement already satisfied: stack_data in /home/codespace/.local/lib/python3.12/site-packages (from ipython<10->ipympl) (0.6.3)
# Requirement already satisfied: comm>=0.1.3 in /home/codespace/.local/lib/python3.12/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.15)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (2.9.0.post0)
# Requirement already satisfied: wcwidth in /home/codespace/.local/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<10->ipympl) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/codespace/.local/lib/python3.12/site-packages (from jedi>=0.16->ipython<10->ipympl) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/codespace/.local/lib/python3.12/site-packages (from pexpect>4.3->ipython<10->ipympl) (0.7.0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.5.0->ipympl) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from stack_data->ipython<10->ipympl) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from stack_data->ipython<10->ipympl) (3.0.0)
# Requirement already satisfied: pure-eval in /home/codespace/.local/lib/python3.12/site-packages (from stack_data->ipython<10->ipympl) (0.2.3)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Requirement already satisfied: upsetplot in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.9.0)
# Requirement already satisfied: pandas>=0.23 in /home/codespace/.local/lib/python3.12/site-packages (from upsetplot) (2.3.1)
# Requirement already satisfied: matplotlib>=2.0 in /home/codespace/.local/lib/python3.12/site-packages (from upsetplot) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=2.0->upsetplot) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=2.0->upsetplot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=2.0->upsetplot) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=2.0->upsetplot) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=2.0->upsetplot) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=2.0->upsetplot) (25.0)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=2.0->upsetplot) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=2.0->upsetplot) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=2.0->upsetplot) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=0.23->upsetplot) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=0.23->upsetplot) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=2.0->upsetplot) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Requirement already satisfied: pillow in /home/codespace/.local/lib/python3.12/site-packages (11.3.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import pandas as pd 
import math
import sys

import numpy as np
from scipy.stats import ttest_ind
import cobra
import matplotlib
from matplotlib_venn import venn3
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
from matplotlib.widgets import CheckButtons
from matplotlib.widgets import Slider
import matplotlib.animation as animation
matplotlib.use('Agg')

source_dir = 'src'
sys.path.append(source_dir)

from transcriptomics.get_gene_transcript_dictionary import get_gene_transcript_dictionary
from transcriptomics.get_reaction_transcript_dictionary import get_reaction_transcript_dictionary

# %%
fpkm_df = pd.read_csv("fpkm_counts_with_annotations.csv")

# %%
fpkm_df.head()
# Out:
#                     Geneid   EBY_1   EBY_2   EBY_3  EBY-U_1  EBY-GNSR_1  \
# 0  jgi|Sacce1|1000|YDL018C   47.55   49.28   46.03    27.44       66.92
# 1  jgi|Sacce1|1001|YDL017W   20.11   20.75   19.72    26.48       25.70
# 2  jgi|Sacce1|1002|YDL016C    5.68    6.50    3.91     4.32        7.41
# 3  jgi|Sacce1|1003|YDL015C  258.04  263.32  271.20   176.40      287.94
# 4  jgi|Sacce1|1004|YDL014W  338.89  352.15  227.14    32.43      264.66
#
#    EBY-GNSR_2  EBY-GNHR_1  EBY-GNHR_2  EBY-GNHR_3  EBY-GNUR_1  EBY-GNUR_2  \
# 0       56.75       26.36       30.20       32.08       45.72       44.23
# 1       28.76       22.21       20.59       22.80       33.20       36.83
# 2        7.81        2.39        2.12        2.39        5.77        2.15
# 3      309.80       97.96      133.22      114.73      172.79      189.77
# 4      275.53       33.94       28.27       20.38       70.73      106.82
#
#    EBY-GNUR_3                         JGI_annotation  \
# 0       46.24                                    NaN
# 1       33.11                         Protein kinase
# 2        3.29                                    NaN
# 3      190.81  3-oxo-5-alpha-steroid 4-dehydrogenase
# 4       72.10                                    NaN
#
#                                      KEGG_annotation
# 0              no KO assigned | (RefSeq) ERP3; Erp3p
# 1  K02214 cell division control protein 7 [EC:2.7...
# 2                                                NaN
# 3  K10258 very-long-chain enoyl-CoA reductase [EC...
# 4  K14563 rRNA 2'-O-methyltransferase fibrillarin...

# %%
fpkm_df.head()
# Out:
#                     Geneid   EBY_1   EBY_2   EBY_3  EBY-U_1  EBY-GNSR_1  \
# 0  jgi|Sacce1|1000|YDL018C   47.55   49.28   46.03    27.44       66.92
# 1  jgi|Sacce1|1001|YDL017W   20.11   20.75   19.72    26.48       25.70
# 2  jgi|Sacce1|1002|YDL016C    5.68    6.50    3.91     4.32        7.41
# 3  jgi|Sacce1|1003|YDL015C  258.04  263.32  271.20   176.40      287.94
# 4  jgi|Sacce1|1004|YDL014W  338.89  352.15  227.14    32.43      264.66
#
#    EBY-GNSR_2  EBY-GNHR_1  EBY-GNHR_2  EBY-GNHR_3  EBY-GNUR_1  EBY-GNUR_2  \
# 0       56.75       26.36       30.20       32.08       45.72       44.23
# 1       28.76       22.21       20.59       22.80       33.20       36.83
# 2        7.81        2.39        2.12        2.39        5.77        2.15
# 3      309.80       97.96      133.22      114.73      172.79      189.77
# 4      275.53       33.94       28.27       20.38       70.73      106.82
#
#    EBY-GNUR_3                         JGI_annotation  \
# 0       46.24                                    NaN
# 1       33.11                         Protein kinase
# 2        3.29                                    NaN
# 3      190.81  3-oxo-5-alpha-steroid 4-dehydrogenase
# 4       72.10                                    NaN
#
#                                      KEGG_annotation
# 0              no KO assigned | (RefSeq) ERP3; Erp3p
# 1  K02214 cell division control protein 7 [EC:2.7...
# 2                                                NaN
# 3  K10258 very-long-chain enoyl-CoA reductase [EC...
# 4  K14563 rRNA 2'-O-methyltransferase fibrillarin...

# %%
column = fpkm_df.drop(columns='JGI_annotation')
column2 = column.drop(columns='KEGG_annotation')
column3 = column2.drop(columns='Geneid')
column_averages = column3.mean()
column_averages.plot(kind='bar', figsize=(18, 12), color=['skyblue','skyblue','skyblue', 'salmon', 'lightgreen','lightgreen','purple','purple','purple','red','red','red'])

# 3. Add a title and labels for clarity
plt.title('Average Counts')
plt.ylabel('Counts')
plt.xlabel('Strains')
plt.xticks(rotation=0) # Keeps the x-axis labels horizontal
plt.tight_layout() # Adjusts plot for a tight layout

# 4. Display the plot
plt.show()
# Out:
# /tmp/ipykernel_2154/3906591000.py:12: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout() # Adjusts plot for a tight layout
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fpkm_df.head()
# Out:
#                     Geneid   EBY_1   EBY_2   EBY_3  EBY-U_1  EBY-GNSR_1  \
# 0  jgi|Sacce1|1000|YDL018C   47.55   49.28   46.03    27.44       66.92
# 1  jgi|Sacce1|1001|YDL017W   20.11   20.75   19.72    26.48       25.70
# 2  jgi|Sacce1|1002|YDL016C    5.68    6.50    3.91     4.32        7.41
# 3  jgi|Sacce1|1003|YDL015C  258.04  263.32  271.20   176.40      287.94
# 4  jgi|Sacce1|1004|YDL014W  338.89  352.15  227.14    32.43      264.66
#
#    EBY-GNSR_2  EBY-GNHR_1  EBY-GNHR_2  EBY-GNHR_3  EBY-GNUR_1  EBY-GNUR_2  \
# 0       56.75       26.36       30.20       32.08       45.72       44.23
# 1       28.76       22.21       20.59       22.80       33.20       36.83
# 2        7.81        2.39        2.12        2.39        5.77        2.15
# 3      309.80       97.96      133.22      114.73      172.79      189.77
# 4      275.53       33.94       28.27       20.38       70.73      106.82
#
#    EBY-GNUR_3                         JGI_annotation  \
# 0       46.24                                    NaN
# 1       33.11                         Protein kinase
# 2        3.29                                    NaN
# 3      190.81  3-oxo-5-alpha-steroid 4-dehydrogenase
# 4       72.10                                    NaN
#
#                                      KEGG_annotation
# 0              no KO assigned | (RefSeq) ERP3; Erp3p
# 1  K02214 cell division control protein 7 [EC:2.7...
# 2                                                NaN
# 3  K10258 very-long-chain enoyl-CoA reductase [EC...
# 4  K14563 rRNA 2'-O-methyltransferase fibrillarin...

# %%
EBY_AVE = fpkm_df[['EBY_1', 'EBY_2', 'EBY_3']].mean(axis=1) # averages the 3 EBY columns
EBYU = fpkm_df[['EBY-U_1']].mean(axis=1) # puts the EBY-U_1 in the same shape as EBY_AVE
EBY_GNSR_AVE = fpkm_df[['EBY-GNSR_1', 'EBY-GNSR_2']].mean(axis=1) # averages 2 GNSR columns
EBY_GNHR_AVE = fpkm_df[['EBY-GNHR_1', 'EBY-GNHR_2', 'EBY-GNHR_3']].mean(axis=1) # averages 3 GNHR columns
EBY_GNUR_AVE = fpkm_df[['EBY-GNUR_1', 'EBY-GNUR_2', 'EBY-GNUR_3']].mean(axis=1) # averages 3 GNUR columns


def calculate_log2fc(treatment_series, control_series, pseudocount=1): # log2fold change function
    """Calculates log2 fold change between two pandas Series."""
    treatment_adjusted = treatment_series + pseudocount
    control_adjusted = control_series + pseudocount
    return np.log2(treatment_adjusted / control_adjusted)

# %%
# Comparison 1: GNSR vs. GNHR
log2fc_gnsr_vs_gnhr = calculate_log2fc(EBY_GNSR_AVE, EBY_GNHR_AVE)

# Comparison 2: GNSR vs. GNUR
log2fc_gnsr_vs_gnur = calculate_log2fc(EBY_GNSR_AVE, EBY_GNUR_AVE)

# Comparison 3: GNSR vs. EBY
log2fc_gnsr_vs_eby = calculate_log2fc(EBY_GNSR_AVE, EBY_AVE)

# Comparison 4: GNUR vs. U
log2fc_gnur_vs_u = calculate_log2fc(EBY_GNUR_AVE, EBYU)

results_df = pd.DataFrame({
    'log2fc_GNSR_vs_GNHR': log2fc_gnsr_vs_gnhr,
    'log2fc_GNSR_vs_GNUR': log2fc_gnsr_vs_gnur,
    'log2fc_GNSR_vs_EBY': log2fc_gnsr_vs_eby,
    'log2fc_GNUR_vs_U': log2fc_gnur_vs_u
})

# Display the first few rows of results
print(results_df.head())
# Out:
#    log2fc_GNSR_vs_GNHR  log2fc_GNSR_vs_GNUR  log2fc_GNSR_vs_EBY  \
# 0             1.040553             0.437547            0.370018
# 1             0.303983            -0.325705            0.413619
# 2             1.383547             0.862141            0.436231
# 3             1.366445             0.693255            0.177329
# 4             3.248247             1.686621           -0.179722
#
#    log2fc_GNUR_vs_U
# 0          0.706100
# 1          0.364552
# 2         -0.167554
# 3          0.064076
# 4          1.332962

# %%
gnsr_cols = ['EBY-GNSR_1', 'EBY-GNSR_2']
eby_cols = ['EBY_1', 'EBY_2', 'EBY_3']
gnhr_cols = ['EBY-GNHR_1', 'EBY-GNHR_2', 'EBY-GNHR_3']
gnur_cols = ['EBY-GNUR_1', 'EBY-GNUR_2', 'EBY-GNUR_3']

# Perform an independent t-test for each row (gene)
# The 'equal_var=False' handles cases where the groups have different variances
# The '.pvalue' at the end extracts just the p-value from the test result
p_values_gnsr_vs_gnhr = stats.ttest_ind(
    fpkm_df[gnsr_cols],
    fpkm_df[gnhr_cols],
    axis=1,
    equal_var=False
).pvalue

p_values_gnsr_vs_gnur = stats.ttest_ind(
    fpkm_df[gnsr_cols],
    fpkm_df[gnur_cols],
    axis=1,
    equal_var=False
).pvalue

p_values_gnsr_vs_eby = stats.ttest_ind(
    fpkm_df[gnsr_cols],
    fpkm_df[eby_cols],
    axis=1,
    equal_var=False
).pvalue

p_values_gnur_vs_u = stats.ttest_ind(
    fpkm_df[gnur_cols],
    fpkm_df['EBY-U_1'],
    axis=1,
    equal_var=False
).pvalue
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:611: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)
# /home/codespace/.local/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:611: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)
# /home/codespace/.local/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:611: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)

# %%
# Create a DataFrame for the first comparison
df1 = pd.DataFrame({
    'log2_fold_change': log2fc_gnsr_vs_gnhr,
    'p_value': p_values_gnsr_vs_gnhr, # The p-values you just calculated
    'comparison': 'GNSR vs. GNHR'
})

# Create a DataFrame for the second comparison
df2 = pd.DataFrame({
    'log2_fold_change': log2fc_gnsr_vs_gnur,
    'p_value': p_values_gnsr_vs_gnur, # The p-values you just calculated
    'comparison': 'GNSR vs. GNUR'
})

# Create a DataFrame for the third comparison
df3= pd.DataFrame({
    'log2_fold_change': log2fc_gnsr_vs_eby,
    'p_value': p_values_gnsr_vs_eby, # The p-values you just calculated
    'comparison': 'GNSR vs. EBY'
})

# Create a DataFrame for the first comparison
df4 = pd.DataFrame({
    'log2_fold_change': log2fc_gnsr_vs_gnhr,
    'p_value': p_values_gnur_vs_u, # The p-values you just calculated
    'comparison': 'GNUR vs. U'
})

plot_df = pd.concat([df1, df2, df3, df4]).reset_index(drop=True) # combining into one dataframe

plot_df['-log10(p_value)'] = -np.log10(plot_df['p_value'].fillna(1))

plot_df_NO_U = pd.concat([df1, df2, df3]).reset_index(drop=True)
plot_df_NO_U['-log10(p_value)'] = -np.log10(plot_df['p_value'].fillna(1))
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plot_df_NO_U.head()
# Out:
#    log2_fold_change   p_value     comparison  -log10(p_value)
# 0          1.040553  0.073900  GNSR vs. GNHR         1.131358
# 1          0.303983  0.133726  GNSR vs. GNHR         0.873785
# 2          1.383547  0.007939  GNSR vs. GNHR         2.100257
# 3          1.366445  0.002520  GNSR vs. GNHR         2.598541
# 4          3.248247  0.000677  GNSR vs. GNHR         3.169231

# %%
plt.figure(figsize=(8, 6))

# Use Seaborn's scatterplot, coloring by the 'comparison' column
sns.scatterplot(
    data=plot_df_NO_U,
    x='log2_fold_change',
    y='-log10(p_value)',
    hue='comparison', # This will color the dots for each comparison group
    alpha=0.6,
    edgecolor='none'
)

# Add lines for significance and fold-change cutoffs (optional)
plt.axhline(y=-np.log10(0.05), color='r', linestyle='--', label='P-value < 0.05')
plt.axvline(x=1, color='b', linestyle='--')
plt.axvline(x=-1, color='b', linestyle='--')

# Customize labels and title
plt.xlabel("log₂ Fold Change")
plt.ylabel("-log₁₀(P-value)")
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

plt.show()
plt.savefig('volcano_plot.png', dpi=300, bbox_inches='tight')

# %%
plt.figure(figsize=(8, 6))

# Use Seaborn's scatterplot, coloring by the 'comparison' column
sns.scatterplot(
    data=plot_df,
    x='log2_fold_change',
    y='-log10(p_value)',
    hue='comparison', # This will color the dots for each comparison group
    alpha=0.6,
    edgecolor='none'
)

# Add lines for significance and fold-change cutoffs (optional)
plt.axhline(y=-np.log10(0.05), color='r', linestyle='--', label='P-value < 0.05')
plt.axvline(x=1, color='b', linestyle='--')
plt.axvline(x=-1, color='b', linestyle='--')

# Customize labels and title
plt.xlabel("log₂ Fold Change")
plt.ylabel("-log₁₀(P-value)")
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

plt.show()

# %%
# %matplotlib widget

fig, ax = plt.subplots(figsize=(10, 7))
plt.subplots_adjust(left=0.1, right=0.8)

lines = {} # Dictionary to store plot artists
for group_name in plot_df_NO_U['comparison'].unique():
    group_df = plot_df_NO_U[plot_df_NO_U['comparison'] == group_name]
    # Use ax.scatter() to plot the data
    line = ax.scatter(
        group_df['log2_fold_change'],
        group_df['-log10(p_value)'],
        label=group_name,
        alpha=0.6,
        edgecolor='none'
    )
    lines[group_name] = line

# Add labels and styling to the main plot
ax.set_xlabel("log₂ Fold Change")
ax.set_ylabel("-log₁₀(P-value)")
ax.set_title("Log2 foldchange Volcano Plot with Interactive Controls no U")
ax.grid(True, linestyle='--', alpha=0.5)
ax.axhline(y=-np.log10(0.05), color='r', linestyle='--', lw=1)


# 3. CREATE THE CHECKBUTTON WIDGET
# Define the area where the buttons will live (right side of the plot)
rax = plt.axes([0.82, 0.4, 0.15, 0.3]) # [left, bottom, width, height]

labels = [str(line.get_label()) for line in lines.values()]
visibility = [line.get_visible() for line in lines.values()]
check = CheckButtons(rax, labels, visibility)

# 4. DEFINE THE FUNCTION TO BE CALLED ON BUTTON CLICK
def update_visibility(label):
    """This function will turn the visibility of a plot line on or off."""
    line = lines[label]
    line.set_visible(not line.get_visible())
    plt.draw() # Redraw the plot to show the change

# 5. CONNECT THE WIDGET TO THE FUNCTION
check.on_clicked(update_visibility)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots(figsize=(10, 7))
plt.subplots_adjust(left=0.1, right=0.8)

lines = {} # Dictionary to store plot artists
for group_name in plot_df_NO_U['comparison'].unique():
    group_df = plot_df_NO_U[plot_df_NO_U['comparison'] == group_name]
    line = ax.scatter(
        group_df['log2_fold_change'],
        group_df['-log10(p_value)'],
        label=group_name,
        alpha=0.6,
        edgecolor='none'
    )
    lines[group_name] = line

# Add labels and styling to the main plot
ax.set_xlabel("log₂ Fold Change")
ax.set_ylabel("-log₁₀(P-value)")
ax.grid(True, linestyle='--', alpha=0.5)
ax.axhline(y=-np.log10(0.05), color='r', linestyle='--', lw=1)

# Create the CheckButtons widget
rax = plt.axes([0.82, 0.4, 0.15, 0.3])
labels = [str(line.get_label()) for line in lines.values()]
check = CheckButtons(rax, labels, [True]*len(labels))

# --- Step 2: Define the Animation Function (with the fix) ---
active_color = 'lightgreen'
inactive_color = 'white'

def update_animation(frame_num, artists, check_widget):
    artist_labels = list(artists.keys())
    
    # Update the visibility of the scatter plot data
    for i, label in enumerate(artist_labels):
        artists[label].set_visible(i == frame_num)
        
    # **FIX IS HERE:** Use .ax.patches to access the rectangles
    for i, patch in enumerate(check_widget.ax.patches):
        patch.set_facecolor(active_color if i == frame_num else inactive_color)
        
    # Update the title to show which group is currently displayed
    ax.set_title(f"Displaying: {artist_labels[frame_num]}")
    
    # Return all the artists that were modified
    return list(artists.values()) + check_widget.ax.patches

# --- Step 3: Create and Save the Animation ---
ani = animation.FuncAnimation(
    fig, 
    update_animation, 
    frames=len(lines),
    fargs=(lines, check),
    interval=800
)

ani.save('volcano_plot_animation.gif', writer='pillow', fps=1)
plt.close(fig) # Close the figure to prevent static display

print("Animated GIF 'volcano_plot_animation.gif' saved successfully!")
# Out:
# Animated GIF 'volcano_plot_animation.gif' saved successfully!

# %%
EBY_1_gene_transcripts = get_gene_transcript_dictionary(fpkm_df, 'EBY_1')
EBY_2_gene_transcripts = get_gene_transcript_dictionary(fpkm_df, 'EBY_2')
EBY_3_gene_transcripts = get_gene_transcript_dictionary(fpkm_df, 'EBY_3')

EBY_U_1_gene_transcripts = get_gene_transcript_dictionary(fpkm_df, 'EBY-U_1')

EBY_GNSR_1_gene_transcripts = get_gene_transcript_dictionary(fpkm_df, 'EBY-GNSR_1')
EBY_GNSR_2_gene_transcripts = get_gene_transcript_dictionary(fpkm_df, 'EBY-GNSR_2')

EBY_GNHR_1_gene_transcripts = get_gene_transcript_dictionary(fpkm_df, 'EBY-GNHR_1')
EBY_GNHR_2_gene_transcripts = get_gene_transcript_dictionary(fpkm_df, 'EBY-GNHR_2')
EBY_GNHR_3_gene_transcripts = get_gene_transcript_dictionary(fpkm_df, 'EBY-GNHR_3')

EBY_GNUR_1_gene_transcripts = get_gene_transcript_dictionary(fpkm_df, 'EBY-GNUR_1')
EBY_GNUR_2_gene_transcripts = get_gene_transcript_dictionary(fpkm_df, 'EBY-GNUR_2')
EBY_GNUR_3_gene_transcripts = get_gene_transcript_dictionary(fpkm_df, 'EBY-GNUR_3')


EBY_1_gene_transcripts
# Out:
# {'': inf,
#  'no KO assigned | (RefSeq) ERP3; Erp3p': 47.55,
#  'K02214 cell division control protein 7 [EC:2.7.11.1] | (RefSeq) CDC7, LSD6, SAS1; serine/threonine protein kinase CDC7': 20.11,
#  nan: 0.92,
#  'K10258 very-long-chain enoyl-CoA reductase [EC:1.3.1.93] | (RefSeq) TSC13; trans-2-enoyl-CoA reductase (NADPH) TSC13': 258.04,
#  "K14563 rRNA 2'-O-methyltransferase fibrillarin [EC:2.1.1.-] | (RefSeq) NOP1, LOT3; rRNA methyltransferase NOP1": 338.89,
#  'K22645 E3 ubiquitin-protein ligase complex SLX5-SLX8 subunit SLX5 [EC:2.3.2.27] | (RefSeq) SLX5, HEX3, ULS2; SUMO-targeted ubiquitin ligase complex subunit SLX5': 25.82,
#  'no KO assigned | (RefSeq) uncharacterized protein': 0.4,
#  'no KO assigned | (RefSeq) GRX6; glutathione-disulfide reductase GRX6': 64.59,
#  'K03358 anaphase-promoting complex subunit 11 | (RefSeq) APC11; anaphase promoting complex subunit 11': 64.2,
#  'K03062 26S proteasome regulatory subunit T2 | (RefSeq) RPT2, YHS4, YTA5; proteasome regulatory particle base subunit RPT2': 166.9,
#  'K19704 protein phosphatase PTC1 [EC:3.1.3.16] | (RefSeq) PTC1, CWH47, KCS2, TPD1; type 2C protein phosphatase PTC1': 42.79,
#  'K15154 mediator of RNA polymerase II transcription subunit 2 | (RefSeq) MED2; Med2p': 48.33,
#  'K02134 F-type H+-transporting ATPase subunit delta | (RefSeq) ATP16; F1F0 ATP synthase subunit delta': 403.45,
#  'K06670 cohesin complex subunit SCC1 | (RefSeq) MCD1, PDS3, RHC21, SCC1; kleisin alpha': 69.47,
#  'K11680 non-histone protein 10 | (RefSeq) NHP10, HMO2; Nhp10p': 95.51,
#  'no KO assigned | (RefSeq) RMD1; Rmd1p': 34.58,
#  'K01194 alpha,alpha-trehalase [EC:3.2.1.28] | (RefSeq) NTH1; alpha,alpha-trehalase NTH1': 34.04,
#  'no KO assigned | (RefSeq) PRM9; pheromone-regulated DUP240 family protein PRM9': 3.02,
#  'K15306 Ran-binding protein 1 | (RefSeq) YRB1, CST20, HTN1, SFO1, STP52; Ran GTPase-binding protein YRB1': 952.87,
#  'no KO assigned | (RefSeq) RCR2, SSH5; Rcr2p': 42.73,
#  'K10958 DNA repair protein RAD57 | (RefSeq) RAD57; putative DNA-dependent ATPase RAD57': 44.17,
#  'K25817 repressor of RNA polymerase III transcription MAF1 | (RefSeq) MAF1; RNA polymerase III-inhibiting protein MAF1': 68.46,
#  'no KO assigned | (RefSeq) SOK1; Sok1p': 41.25,
#  'K01817 phosphoribosylanthranilate isomerase [EC:5.3.1.24] | (RefSeq) TRP1; phosphoribosylanthranilate isomerase TRP1': 35.85,
#  'K00849 galactokinase [EC:2.7.1.6] | (RefSeq) GAL3; transcriptional regulator GAL3': 3.43,
#  'no KO assigned | (RefSeq) MST28; DUP240 family protein MST28': 14.27,
#  'K08712 ATP-binding cassette, subfamily G (WHITE), member 2, SNQ2 | (RefSeq) SNQ2; ATP-binding cassette transporter SNQ2': 46.31,
#  'K02930 large subunit ribosomal protein L4e | (RefSeq) RPL4B; ribosomal 60S subunit protein L4B': 1144.55,
#  'K10732 GINS complex subunit 1 | (RefSeq) PSF1, CDC101; DNA replication protein PSF1': 43.46,
#  'no KO assigned | (RefSeq) RAD61, WPL1; Rad61p': 16.98,
#  'no KO assigned | (RefSeq) HED1; Hed1p': 1.56,
#  'K11553 DASH complex subunit DAD1 | (RefSeq) DAD1; Dad1p': 64.97,
#  'K07756 inositol-hexakisphosphate 5-kinase [EC:2.7.4.21] | (RefSeq) KCS1; inositol polyphosphate kinase KCS1': 43.31,
#  'no KO assigned | (RefSeq) MLG1; putative acyltransferase': 1.73,
#  'K00605 glycine cleavage system T protein (aminomethyltransferase) [EC:2.1.2.10] | (RefSeq) GCV1, GSD1; glycine decarboxylase subunit T': 292.02,
#  'K00624 carnitine O-acetyltransferase [EC:2.3.1.7] | (RefSeq) YAT1; carnitine O-acetyltransferase YAT1': 1.97,
#  'K00876 uridine kinase [EC:2.7.1.48] | (RefSeq) DAS2, RRT3; putative uridine kinase DAS2': 64.1,
#  'K13025 ATP-dependent RNA helicase [EC:5.6.2.7] | (RefSeq) FAL1; ATP-dependent RNA helicase FAL1': 52.2,
#  'K21144 autophagy-related protein 31 | (RefSeq) ATG31, CIS1; Atg31p': 20.06,
#  'K01875 seryl-tRNA synthetase [EC:6.1.1.11] | (RefSeq) SES1; serine--tRNA ligase SES1': 646.91,
#  'K02949 small subunit ribosomal protein S11e | (RefSeq) RPS11A; ribosomal 40S subunit protein S11A': 1711.46,
#  'K09424 Myb-like DNA-binding protein REB1 | (RefSeq) NSI1, YTT1; Nsi1p': 41.4,
#  'K17600 vacuolar protein sorting-associated protein 54 | (RefSeq) VPS54, CGP1, LUV1, TCS3; Vps54p': 23.18,
#  'no KO assigned | (RefSeq) REG1, HEX2, PZF240, SPP43, SRN1; protein phosphatase regulator REG1': 70.0,
#  'K10570 DNA excision repair protein ERCC-8 | (RefSeq) RAD28; Rad28p': 12.79,
#  'no KO assigned | (RefSeq) MIX14, MIC14; Mix14p': 50.59,
#  'K03809 NAD(P)H dehydrogenase (quinone) [EC:1.6.5.2] | (RefSeq) PST2; flavodoxin-like fold family protein': 250.28,
#  'no KO assigned | (RefSeq) MRH1; Mrh1p': 2970.58,
#  'no KO assigned | (RefSeq) LYS14; Lys14p': 64.43,
#  'no KO assigned | (RefSeq) CPP3; cysteine-rich palmitoylated domain-containing protein CPP3': 8.35,
#  'K01626 3-deoxy-7-phosphoheptulonate synthase [EC:2.5.1.54] | (RefSeq) ARO3; 3-deoxy-7-phosphoheptulonate synthase ARO3': 428.49,
#  'K05605 3-hydroxyisobutyryl-CoA hydrolase [EC:3.1.2.4] | (RefSeq) EHD3, mS47; mitochondrial 37S ribosomal protein EHD3': 36.77,
#  'K04567 lysyl-tRNA synthetase, class II [EC:6.1.1.6] | (RefSeq) KRS1, GCD5; lysine--tRNA ligase KRS1': 788.01,
#  'K20456 oxysterol-binding protein 1 | (RefSeq) SWH1, OSH1, YAR044W; oxysterol-binding protein related protein SWH1': 15.61,
#  'K01536 P-type Na+/K+ transporter [EC:7.2.2.3 7.2.2.-] | (RefSeq) ENA5; putative Na(+)-exporting P-type ATPase ENA5': 7.23,
#  'K01536 P-type Na+/K+ transporter [EC:7.2.2.3 7.2.2.-] | (RefSeq) ENA2; Na(+)-exporting P-type ATPase ENA2': 1.13,
#  'K01536 P-type Na+/K+ transporter [EC:7.2.2.3 7.2.2.-] | (RefSeq) ENA1, HOR6, PMR2; Na(+)/Li(+)-exporting P-type ATPase ENA1': 10.13,
#  'K02946 small subunit ribosomal protein S10 | (RefSeq) RSM10, uS10m; mitochondrial 37S ribosomal protein RSM10': 96.6,
#  'no KO assigned | (RefSeq) NRG1; transcriptional regulator NRG1': 59.89,
#  'K00228 coproporphyrinogen III oxidase [EC:1.3.3.3] | (RefSeq) HEM13; coproporphyrinogen oxidase': 56.78,
#  'K03019 DNA-directed RNA polymerase III subunit RPC11 | (RefSeq) RPC11; DNA-directed RNA polymerase III core subunit RPC11': 202.42,
#  'K16261 yeast amino acid transporter | (RefSeq) BAP3, PAP1; amino acid transporter BAP3': 153.95,
#  'K01599 uroporphyrinogen decarboxylase [EC:4.1.1.37] | (RefSeq) HEM12, HEM6; uroporphyrinogen decarboxylase HEM12': 160.58,
#  'K26089 ankyrin repeat and zinc finger domain-containing protein 1 | (RefSeq) VMS1; Vms1p': 37.65,
#  'K01803 triosephosphate isomerase (TIM) [EC:5.3.1.1] | (RefSeq) TPI1; triose-phosphate isomerase TPI1': 6218.71,
#  'no KO assigned | (RefSeq) DET1; acid phosphatase DET1': 77.64,
#  'K02309 regulatory subunit for Cdc7p protein kinase | (RefSeq) DBF4, DNA52, LSD7; protein serine/threonine kinase activating protein DBF4': 58.19,
#  'K02207 ubiquitin-conjugating enzyme E2 R [EC:2.3.2.23] | (RefSeq) CDC34, DNA6, UBC3; SCF E2 ubiquitin-protein ligase catalytic subunit CDC34': 145.14,
#  'no KO assigned | (RefSeq) PST1, HPF2; Pst1p': 400.17,
#  'no KO assigned | (RefSeq) EMC10; Emc10p': 169.64,
#  'K10088 protein OS-9 | (RefSeq) YOS9; Yos9p': 33.11,
#  'no KO assigned | (RefSeq) FLO1, FLO2, FLO4; flocculin FLO1': 6.58,
#  'K01046 triacylglycerol lipase [EC:3.1.1.3] | (RefSeq) TGL2; triglyceride lipase': 17.22,
#  'K06689 ubiquitin-conjugating enzyme E2 D [EC:2.3.2.23] | (RefSeq) UBC5; E2 ubiquitin-conjugating protein UBC5': 45.77,
#  'K14832 ribosome biogenesis protein MAK21 | (RefSeq) MAK21, NOC1; RNA-binding ribosome biosynthesis protein MAK21': 173.05,
#  'K00654 serine palmitoyltransferase [EC:2.3.1.50] | (RefSeq) LCB2, SCS1, TSC1; serine C-palmitoyltransferase LCB2': 165.89,
#  'no KO assigned | (RefSeq) AIM7, GMF1; Aim7p': 125.2,
#  'K02953 small subunit ribosomal protein S13e | (RefSeq) RPS13, RPS13B, RPS13C; ribosomal 40S subunit protein S13': 2939.37,
#  'no KO assigned | (RefSeq) RRG1, MTA2; Rrg1p': 24.55,
#  'K20827 RNA polymerase II-associated protein 2 [EC:3.1.3.16] | (RefSeq) RTR2; putative protein-serine/threonine phosphatase': 19.68,
#  'K18046 tyrosine-protein phosphatase OCA6 [EC:3.1.3.48] | (RefSeq) OCA6; protein-tyrosine-phosphatase': 71.08,
#  'no KO assigned | (RefSeq) DOS2; Dos2p': 79.42,
#  'K11839 ubiquitin carboxyl-terminal hydrolase 8 [EC:3.4.19.12] | (RefSeq) DOA4, DOS1, MUT4, NPI2, SSV7, UBP4; ubiquitin-specific protease DOA4': 13.6,
#  'no KO assigned | (RefSeq) FMP16; Fmp16p': 11.34,
#  'no KO assigned | (RefSeq) PAA1; polyamine acetyltransferase': 307.14,
#  'K22725 mannosyl-inositol-phosphoceramide inositolphosphotransferase [EC:2.7.1.228] | (RefSeq) IPT1, KTI6, MIC2, SYR4; inositolphosphotransferase': 111.5,
#  'K11774 SWI/SNF complex component SNF11 | (RefSeq) SNF11; Snf11p': 112.21,
#  'K16055 trehalose 6-phosphate synthase/phosphatase [EC:2.4.1.15 3.1.3.12] | (RefSeq) TPS2, HOG2, PFK3; trehalose-phosphatase TPS2': 29.18,
#  'K15423 serine/threonine-protein phosphatase 4 catalytic subunit [EC:3.1.3.16] | (RefSeq) PPH3; phosphoprotein phosphatase PP4 catalytic subunit PPH3': 67.09,
#  'K10957 DNA repair protein RAD55 | (RefSeq) RAD55; putative DNA-dependent ATPase RAD55': 13.05,
#  'no KO assigned | (RefSeq) SED1; Sed1p': 1451.09,
#  'no KO assigned | (RefSeq) SHU2; Shu2p': 20.49,
#  'K18187 protein PET100, fungi type | (RefSeq) PET100; Pet100p': 83.51,
#  'K10845 TFIIH basal transcription factor complex TTD-A subunit | (RefSeq) TFB5; TFIIH complex subunit TFB5': 61.65,
#  'K20184 vacuolar protein sorting-associated protein 41 | (RefSeq) VPS41, CVT8, FET2, SVL2, VAM2, VPL20; Vps41p': 17.77,
#  'no KO assigned | (RefSeq) PDC2; Pdc2p': 39.3,
#  'K11117 protein STN1 | (RefSeq) STN1; Stn1p': 28.86,
#  'K14850 ribosomal RNA-processing protein 8 [EC:2.1.1.287] | (RefSeq) RRP8; 25S rRNA (adenine645-N1)-methyltransferase': 114.74,
#  'K26752 golgi apparatus membrane protein TVP23 | (RefSeq) TVP23; Tvp23p': 64.76,
#  'no KO assigned | (RefSeq) AFR1; Afr1p': 15.66,
#  'K07342 protein transport protein SEC61 subunit gamma and related proteins | (RefSeq) SSS1; translocon subunit SSS1': 867.29,
#  'K14849 ribosomal RNA-processing protein 1 | (RefSeq) RRP1; Rrp1p': 165.8,
#  'K12819 pre-mRNA-processing factor SLU7 | (RefSeq) SLU7, SLT17; mRNA splicing protein SLU7': 27.05,
#  'no KO assigned | (RefSeq) VTC5; Vtc5p': 42.01,
#  'no KO assigned | (RefSeq) ILT1; Ilt1p': 43.49,
#  'K06174 ATP-binding cassette, sub-family E, member 1 | (RefSeq) RLI1; Fe-S cluster-binding ribosome biosynthesis protein': 240.71,
#  'K10580 ubiquitin-conjugating enzyme E2 N [EC:2.3.2.23] | (RefSeq) UBC13; E2 ubiquitin-conjugating protein UBC13': 140.9,
#  'K01530 phospholipid-translocating ATPase [EC:7.6.2.1] | (RefSeq) DNF2; aminophospholipid-translocating P4-type ATPase DNF2': 29.16,
#  'K19798 transcriptional activator/repressor GIS1 | (RefSeq) GIS1; histone demethylase GIS1': 13.23,
#  'K08737 DNA mismatch repair protein MSH6 | (RefSeq) MSH6, PMS3, PMS6; mismatch repair ATPase MSH6': 31.08,
#  'no KO assigned | (RefSeq) GRX3; monothiol glutaredoxin GRX3': 116.51,
#  'K06630 14-3-3 protein epsilon | (RefSeq) BMH2, SCD3; 14-3-3 family protein BMH2': 495.25,
#  'K26750 golgi apparatus membrane protein TVP15 | (RefSeq) TVP15; Tvp15p': 77.87,
#  'K14813 metalloprotease ARX1 [EC:3.-.-.-] | (RefSeq) ARX1; putative hydrolase': 202.89,
#  'K11239 pheromone-response scaffold protein | (RefSeq) STE5, HMD3, NUL3; Ste5p': 19.22,
#  'no KO assigned | (RefSeq) SPO71; Spo71p': 7.86,
#  'K23544 serine incorporator 1 | (RefSeq) TMS1; Tms1p': 50.95,
#  'no KO assigned | (RefSeq) ARP10; Arp10p': 3.22,
#  'K17086 transmembrane 9 superfamily member 2/4 | (RefSeq) TMN2; Tmn2p': 22.75,
#  'K20305 trafficking protein particle complex subunit 8 | (RefSeq) TRS85, GSG1, MUM1; Trs85p': 26.91,
#  'K00875 D-ribulokinase [EC:2.7.1.47] | (RefSeq) putative phosphotransferase': 23.93,
#  'K12577 DNA replication fork-blocking protein FOB1 | (RefSeq) FOB1, HRM1; replication fork barrier binding protein FOB1': 38.2,
#  'K00814 alanine transaminase [EC:2.6.1.2] | (RefSeq) ALT2; alanine transaminase ALT2': 54.98,
#  'K02627 cell cycle regulator | (RefSeq) PDS1; securin': 32.53,
#  'K02914 large subunit ribosomal protein L34 | (RefSeq) MRX14, bL34m; putative mitochondrial 54S ribosomal protein': 122.26,
#  'K02863 large subunit ribosomal protein L1 | (RefSeq) MRPL1, uL1m; mitochondrial 54S ribosomal protein MRPL1': 65.38,
#  'K15027 translation initiation factor 2D | (RefSeq) TMA64; Tma64p': 40.35,
#  'K03351 anaphase-promoting complex subunit 4 | (RefSeq) APC4; anaphase promoting complex subunit 4': 14.32,
#  'no KO assigned | (RefSeq) VBA4; Vba4p': 72.11,
#  'no KO assigned | (RefSeq) COX26; Cox26p': 18.35,
#  'K00555 tRNA (guanine26-N2/guanine27-N2)-dimethyltransferase [EC:2.1.1.215 2.1.1.216] | (RefSeq) TRM1; tRNA (guanine26-N2)-dimethyltransferase': 117.39,
#  'K02326 DNA polymerase epsilon subunit 3 [EC:2.7.7.7] | (RefSeq) DPB4; DNA polymerase epsilon noncatalytic subunit': 81.1,
#  'K19852 serine/threonine protein kinase KIN1/2 [EC:2.7.11.1] | (RefSeq) KIN1; serine/threonine protein kinase KIN1': 11.77,
#  'K09102 heteromeric Ino2p/Ino4p transcription factor | (RefSeq) INO2, DIE1, SCS1; Ino2p': 77.7,
#  'no KO assigned | (RefSeq) ECM18; alpha/beta hydrolase family protein': 10.78,
#  'K20003 palmitoyltransferase ZDHHC4 [EC:2.3.1.225] | (RefSeq) SWF1, PSL10; palmitoyltransferase SWF1': 17.1,
#  'K13830 pentafunctional AROM polypeptide [EC:4.2.3.4 4.2.1.10 1.1.1.25 2.7.1.71 2.5.1.19] | (RefSeq) ARO1; pentafunctional protein ARO1p': 86.15,
#  'K20409 SEA/GATOR complex protein SEA3/WDR59 | (RefSeq) MTC5, SEA3; Mtc5p': 19.56,
#  'K17275 plastin-1 | (RefSeq) SAC6, ABP67; fimbrin': 211.61,
#  'no KO assigned | (RefSeq) FIN1; Fin1p': 38.04,
#  'no KO assigned | (RefSeq) MRX16; Mrx16p': 18.48,
#  'K05665 ATP-binding cassette, subfamily C (CFTR/MRP), member 1 [EC:7.6.2.3] | (RefSeq) YCF1; ATP-binding cassette glutathione S-conjugate transporter YCF1': 50.61,
#  'K23458 repressible acid phosphatase [EC:3.1.3.2] | (RefSeq) PHO11; acid phosphatase PHO11': 3.82,
#  'K20477 RAB6A-GEF complex partner protein 2 | (RefSeq) RGP1; Rgp1p': 33.11,
#  'K18712 THO complex subunit HPR1 | (RefSeq) HPR1, TRF1; Hpr1p': 35.95,
#  'K12158 ubiquitin-like protein Nedd8 | (RefSeq) RUB1; NEDD8 family protein RUB1': 221.22,
#  'K19589 release factor glutamine methyltransferase [EC:2.1.1.297] | (RefSeq) MTQ2; S-adenosylmethionine-dependent methyltransferase': 67.61,
#  'K26680 protein dopey | (RefSeq) DOP1; Dop1p': 23.1,
#  'K13341 peroxin-7 | (RefSeq) PEX7, PAS7, PEB1; Pex7p': 29.58,
#  'no KO assigned | (RefSeq) SAN1; ubiquitin-protein ligase SAN1': 30.79,
#  'K06009 yapsin 1/2 [EC:3.4.23.41] | (RefSeq) MKC7, YPS2; aspartyl protease': 74.59,
#  'K03126 transcription initiation factor TFIID subunit 12 | (RefSeq) TAF12, TAF61, TAF68; Taf12p': 91.05,
#  'K09202 regulatory protein SWI5 | (RefSeq) SWI5; DNA-binding transcription factor SWI5': 68.03,
#  'K00894 ethanolamine kinase [EC:2.7.1.82] | (RefSeq) EKI1; bifunctional choline kinase/ethanolamine kinase EKI1': 42.09,
#  'K00658 2-oxoglutarate dehydrogenase E2 component (dihydrolipoamide succinyltransferase) [EC:2.3.1.61] | (RefSeq) KGD2; dihydrolipoyl transsuccinylase': 137.64,
#  'K17978 nuclear migration protein NUM1 | (RefSeq) NUM1, PAC12; Num1p': 19.18,
#  'no KO assigned | (RefSeq) CTH1; putative mRNA-binding protein CTH1': 53.21,
#  'no KO assigned | (RefSeq) GIR2; Gir2p': 192.36,
#  'K12471 epsin | (RefSeq) ENT5; Ent5p': 67.33,
#  'K01802 peptidylprolyl isomerase [EC:5.2.1.8] | (RefSeq) CPR1, CPH1, CYP1; peptidylprolyl isomerase CPR1': 2721.8,
#  'K03001 DNA-directed RNA polymerase I subunit RPA14 | (RefSeq) RPA14; DNA-directed RNA polymerase I subunit RPA14': 63.56,
#  'K00133 aspartate-semialdehyde dehydrogenase [EC:1.2.1.11] | (RefSeq) HOM2, THR2; aspartate-semialdehyde dehydrogenase': 737.71,
#  'K23719 nuclear mRNA export protein SAC3 | (RefSeq) SAC3, LEP1; Sac3p': 28.78,
#  'K16261 yeast amino acid transporter | (RefSeq) SSY1, RAA1, SHR10; Ssy1p': 24.61,
#  'no KO assigned | (RefSeq) ACL4; Acl4p': 162.47,
#  'no KO assigned | (RefSeq) NBP2; Nbp2p': 61.77,
#  'K12863 protein CWC15 | (RefSeq) CWC15; U2-type spliceosomal complex subunit CWC15': 53.19,
#  'K15292 syntaxin-binding protein 1 | (RefSeq) SEC1; Sec1p': 30.65,
#  'K15443 tRNA (guanine-N(7)-)-methyltransferase subunit TRM82 | (RefSeq) TRM82; Trm82p': 135.78,
#  'K17637 exocyst complex component 2 | (RefSeq) SEC5; exocyst subunit SEC5': 35.31,
#  'K03134 transcription initiation factor TFIID subunit 10 | (RefSeq) TAF10, TAF23, TAF25; Taf10p': 119.59,
#  'K09554 cell division cycle protein 37 | (RefSeq) CDC37, SMO1; Cdc37p': 99.06,
#  'no KO assigned | (RefSeq) STB3; Stb3p': 29.82,
#  'K18442 brefeldin A-inhibited guanine nucleotide-exchange protein | (RefSeq) SEC7; Arf family guanine nucleotide exchange factor SEC7': 43.62,
#  'K13993 HSP20 family protein | (RefSeq) HSP42; heat shock protein HSP42': 17.2,
#  'K03267 peptide chain release factor subunit 3 | (RefSeq) SUP35, GST1, PNM2, SAL3, SUF12, SUP2, SUP36; translation termination factor GTPase eRF3': 278.07,
#  'K00915 inositol-polyphosphate multikinase [EC:2.7.1.140 2.7.1.151] | (RefSeq) ARG82, ARGR3, IPK2; inositol polyphosphate multikinase': 20.19,
#  'K22483 transcriptional regulator HMO1 | (RefSeq) HMO1, HSM2; Hmo1p': 261.75,
#  'K17413 small subunit ribosomal protein S35 | (RefSeq) RSM24, mS35; mitochondrial 37S ribosomal protein RSM24': 56.28,
#  'K11315 transcriptional adapter 3 | (RefSeq) NGG1, ADA3, SWI7; histone acetyltransferase NGG1': 45.37,
#  'K04649 ubiquitin-conjugating enzyme (huntingtin interacting protein 2) [EC:2.3.2.23] | (RefSeq) UBC1; E2 ubiquitin-conjugating protein UBC1': 178.86,
#  'K00237 succinate dehydrogenase (ubiquinone) membrane anchor subunit | (RefSeq) SDH4, ACN18; succinate dehydrogenase membrane anchor subunit SDH4': 193.94,
#  'K24365 COP9 signalosome complex subunit 9 | (RefSeq) CSN9; Csn9p': 29.77,
#  'no KO assigned | (RefSeq) NVJ3; Nvj3p': 25.25,
#  'K06672 cohesin loading factor subunit SCC2 | (RefSeq) SCC2; cohesin-loading factor complex subunit SCC2': 17.25,
#  'K11402 something about silencing protein 4 | (RefSeq) SAS4; Sas4p': 32.43,
#  'K23362 ethanolamine phosphate phosphodiesterase [EC:3.1.-.-] | (RefSeq) CDC1, DSC1, DSR1, ESP2; putative lipid phosphatase CDC1': 58.31,
#  'no KO assigned | (RefSeq) PLP1; Plp1p': 39.71,
#  'no KO assigned | (RefSeq) ATC1, LIC4; Atc1p': 104.68,
#  'K27966 PRELI domain-containing protein 3, mitochondrial | (RefSeq) UPS3, GEP2; Ups3p': 17.62,
#  'K27163 SRP-independent targeting protein 1 | (RefSeq) SND1; Snd1p': 64.6,
#  'K09498 T-complex protein 1 subunit zeta | (RefSeq) CCT6, HTR3, TCP20, TCP6; chaperonin-containing T-complex subunit CCT6': 281.82,
#  'K19998 sec1 family domain-containing protein 1 | (RefSeq) SLY1; syntaxin-binding protein': 69.39,
#  'K04499 RuvB-like protein 1 [EC:5.6.2.4] | (RefSeq) RVB1, TIH1, TIP49, TIP49A; RuvB family ATP-dependent DNA helicase pontin': 223.43,
#  'K11121 NAD-dependent protein deacetylase SIR2 [EC:2.3.1.286] | (RefSeq) HST4; NAD-dependent histone deacetylase HST4': 16.81,
#  'K18716 nucleoporin NUP42 | (RefSeq) NUP42, RIP1, UIP1; FG-nucleoporin NUP42': 25.3,
#  'K17679 ATP-dependent RNA helicase MSS116, mitochondrial [EC:5.6.2.7] | (RefSeq) MSS116; ATP-dependent RNA helicase': 150.14,
#  'K15543 RNA end formation protein 2 | (RefSeq) REF2; RNA-processing protein REF2': 36.53,
#  'K00859 dephospho-CoA kinase [EC:2.7.1.24] | (RefSeq) CAB5; putative dephospho-CoA kinase': 66.8,
#  'K17665 cytochrome b translational activator protein CBS2, mitochondrial | (RefSeq) CBS2, CBP7; Cbs2p': 33.06,
#  'K27349 ribosomal lysine N-methyltransferase 2 [EC:2.1.1.-] | (RefSeq) RKM2; protein-lysine N-methyltransferase': 38.54,
#  'no KO assigned | (RefSeq) VPS64, FAR9; Vps64p': 24.08,
#  'K11572 DASH complex subunit SPC19 | (RefSeq) SPC19; Spc19p': 38.37,
#  'K25485 regulator of V-ATPase in vacuolar membrane protein 2 | (RefSeq) RAV2; Rav2p': 32.58,
#  'K18586 4-hydroxy-3-methoxy-5-polyprenylbenzoate decarboxylase [EC:4.1.1.130] | (RefSeq) COQ4; ubiquinone biosynthesis protein COQ4': 29.76,
#  'K14692 solute carrier family 30 (zinc transporter), member 5/7 | (RefSeq) MSC2; metal cation transporter MSC2': 27.98,
#  'K11132 telomere elongation protein [EC:2.7.7.-] | (RefSeq) EBS1; Ebs1p': 55.78,
#  'K09243 transcriptional regulatory protein UME6 | (RefSeq) UME6, CAR80, NIM2, RIM16; DNA-binding transcriptional regulator UME6': 14.63,
#  'K00889 1-phosphatidylinositol-4-phosphate 5-kinase [EC:2.7.1.68] | (RefSeq) MSS4; 1-phosphatidylinositol-4-phosphate 5-kinase': 53.94,
#  'no KO assigned | (RefSeq) CPP2; cysteine-rich palmitoylated domain-containing protein CPP2': 394.33,
#  'no KO assigned | (RefSeq) PAU9; seripauperin PAU9': 0.0,
#  'K03240 translation initiation factor eIF-2B subunit epsilon | (RefSeq) GCD6; translation initiation factor eIF2B catalytic subunit epsilon': 113.85,
#  'K09493 T-complex protein 1 subunit alpha | (RefSeq) TCP1, CCT1; chaperonin-containing T-complex alpha subunit TCP1': 205.01,
#  'no KO assigned | (RefSeq) UPC2, MOX4; Upc2p': 17.52,
#  'K26216 activator of Hsp90 ATPase protein 1 | (RefSeq) AHA1; Aha1p': 67.26,
#  'K09466 zinc finger protein ADR1 | (RefSeq) ADR1; DNA-binding transcription factor ADR1': 17.87,
#  'K06661 DNA repair protein RAD9 | (RefSeq) RAD9; chromatin-binding protein RAD9': 23.98,
#  'K16947 sporulation-regulated protein 28 | (RefSeq) SPR28; septin SPR28': 1.41,
#  'no KO assigned | (RefSeq) MFB1; Mfb1p': 47.58,
#  'K08288 protein kinase C substrate 80K-H | (RefSeq) GTB1; Gtb1p': 34.96,
#  'no KO assigned | (RefSeq) CRF1; Crf1p': 3.0,
#  'K11252 histone H2B | (RefSeq) HTB1, SPT12; histone H2B': 2243.2,
#  'K11251 histone H2A | (RefSeq) HTA1, H2A1, SPT11; histone H2A': 2144.85,
#  'K00939 adenylate kinase [EC:2.7.4.3] | (RefSeq) ADK1, AKY1, AKY2; adenylate kinase ADK1': 1193.72,
#  'K11123 regulatory protein SIR4 | (RefSeq) SIR4, ASD1, STE9, UTH2; chromatin-silencing protein SIR4': 19.29,
#  'K14400 pre-mRNA cleavage complex 2 protein Pcf11 | (RefSeq) PCF11; Pcf11p': 33.61,
#  'no KO assigned | (RefSeq) IVY1; Ivy1p': 35.28,
#  'K18184 cytochrome c oxidase assembly protein subunit 20 | (RefSeq) COX20; Cox20p': 30.24,
#  'K00643 5-aminolevulinate synthase [EC:2.3.1.37] | (RefSeq) HEM1, CYD1, OLE3; 5-aminolevulinate synthase': 73.61,
#  'no KO assigned | (RefSeq) RTN1; Rtn1p': 647.28,
#  'K01705 homoaconitate hydratase [EC:4.2.1.36] | (RefSeq) LYS4, LYS3; homoaconitate hydratase LYS4': 190.04,
#  'K13217 pre-mRNA-processing factor 39 | (RefSeq) PRP42, MUD16, SNU65; mRNA splicing protein PRP42': 35.93,
#  'K00861 riboflavin kinase [EC:2.7.1.26] | (RefSeq) FMN1; riboflavin kinase': 40.13,
#  'K02931 large subunit ribosomal protein L5 | (RefSeq) MRPL7, uL5m; mitochondrial 54S ribosomal protein YmL7/YmL5': 67.26,
#  'K17301 coatomer subunit beta | (RefSeq) SEC26; coatomer subunit beta': 155.98,
#  'no KO assigned | (RefSeq) SNU56, MUD10; Snu56p': 30.53,
#  'no KO assigned | (RefSeq) MIX23, MIC23; Mix23p': 81.85,
#  'K01426 amidase [EC:3.5.1.4] | (RefSeq) AMD2; putative amidase': 19.23,
#  'K12858 ATP-dependent RNA helicase DDX23/PRP28 [EC:5.6.2.7] | (RefSeq) PRP28; mRNA splicing protein PRP28': 25.66,
#  'K13342 peroxin-5 | (RefSeq) PEX5, PAS10; Pex5p': 37.36,
#  'K05531 mannan polymerase II complex MNN10 subunit [EC:2.4.1.-] | (RefSeq) MNN10, BED1, REC41, SLC2; alpha-1,6-mannosyltransferase': 169.29,
#  'K20303 trafficking protein particle complex subunit 4 | (RefSeq) TRS23; TRAPP subunit TRS23': 28.69,
#  'no KO assigned | (RefSeq) VHS1; putative serine/threonine protein kinase VHS1': 16.15,
#  'K00851 gluconokinase [EC:2.7.1.12] | (RefSeq) gluconokinase': 67.86,
#  'K08518 syntaxin-binding protein 5 | (RefSeq) SRO77, SNI2, SOP2; putative Rab GTPase-binding protein SRO77': 8.08,
#  'no KO assigned | (RefSeq) PAM1; Pam1p': 56.71,
#  'K01527 nascent polypeptide-associated complex subunit beta | (RefSeq) BTT1; CCR4-NOT core subunit BTT1': 33.28,
#  'no KO assigned | (RefSeq) MET32; Met32p': 9.48,
#  'K11551 central kinetochore subunit Mis15/CHL4 | (RefSeq) CHL4, CTF17, MCM17; Chl4p': 17.0,
#  'K23333 E3 ubiquitin-protein transferase RMND5 [EC:2.3.2.27] | (RefSeq) RMD5, GID2; ubiquitin-protein ligase RMD5': 15.66,
#  'K03781 catalase [EC:1.11.1.6] | (RefSeq) CTA1; catalase A': 4.46,
#  'K05302 N-lysine methyltransferase SETD6 [EC:2.1.1.-] | (RefSeq) RKM4, RMS1, SET7; ribosomal lysine N-methyltransferase': 62.96,
#  'K03695 ATP-dependent Clp protease ATP-binding subunit ClpB | (RefSeq) HSP78; chaperone ATPase HSP78': 20.46,
#  'K09043 AP-1-like transcription factor | (RefSeq) YAP6, HAL7; Yap6p': 4.95,
#  'K02677 classical protein kinase C alpha type [EC:2.7.11.13] | (RefSeq) PKC1, CLY15, CLY5, CLY7, HPO2, RSF8, STT1; protein kinase C': 33.28,
#  'K12416 anaphase-promoting complex subunit SWM1 | (RefSeq) SWM1, APC13; Swm1p': 66.49,
#  'K01210 glucan 1,3-beta-glucosidase [EC:3.2.1.58] | (RefSeq) EXG2; glucan exo-1,3-beta-glucosidase': 67.37,
#  'no KO assigned | (RefSeq) DIN7, DIN3; exodeoxyribonuclease DIN7': 6.49,
#  'K20032 palmitoyltransferase ZDHHC13/17 [EC:2.3.1.225] | (RefSeq) AKR1; palmitoyltransferase AKR1': 78.13,
#  'K13346 peroxin-10 | (RefSeq) PEX10, PAS4; ubiquitin-protein ligase peroxin 10': 30.73,
#  'K22381 E3 ubiquitin-protein ligase ZNF598 [EC:2.3.2.27] | (RefSeq) HEL2, RQT1; E3 ubiquitin-protein ligase HEL2': 71.8,
#  'K24730 cytosolic iron-sulfur protein assembly protein CIAO1 | (RefSeq) CIA1; iron-sulfur cluster assembly protein CIA1': 82.2,
#  'K01867 tryptophanyl-tRNA synthetase [EC:6.1.1.2] | (RefSeq) MSW1; tryptophan--tRNA ligase MSW1': 26.45,
#  'K20407 SEA/GATOR complex protein SEA4/MIOS | (RefSeq) SEA4, YBL103C-A; Sea4p': 15.98,
#  'no KO assigned | (RefSeq) FLO9; flocculin FLO9': 1.99,
#  'K17686 P-type Cu+ transporter [EC:7.2.2.8] | (RefSeq) CCC2; Cu(2+)-transporting P-type ATPase CCC2': 7.45,
#  'K01069 hydroxyacylglutathione hydrolase [EC:3.1.2.6] | (RefSeq) GLO2; hydroxyacylglutathione hydrolase GLO2': 104.18,
#  'no KO assigned | (RefSeq) DON1; Don1p': 6.14,
#  'no KO assigned | (RefSeq) TLD1, BSC2; triglyceride-associated lipolysis regulator TLD1': 58.81,
#  'no KO assigned | (RefSeq) PMP3, SNA1; Pmp3p': 2007.16,
#  'no KO assigned | (RefSeq) MTH1, BPC1, DGT1, HTR1; Mth1p': 17.32,
#  'no KO assigned | (RefSeq) RNH202; Rnh202p': 50.05,
#  'no KO assigned | (RefSeq) RTG3; Rtg3p': 46.1,
#  'K03678 exosome complex component RRP45 | (RefSeq) RRP45; exosome non-catalytic core subunit RRP45': 125.75,
#  'no KO assigned | (RefSeq) PHM6; Phm6p': 14.29,
#  'K23499 required for meiotic nuclear division protein 1 | (RefSeq) MRX10; Mrx10p': 17.18,
#  'K16196 eukaryotic translation initiation factor 2-alpha kinase 4 [EC:2.7.11.1] | (RefSeq) GCN2, AAS1, AAS102, NDR2; serine/threonine-protein kinase GCN2': 21.03,
#  'K18693 diacylglycerol diphosphate phosphatase / phosphatidate phosphatase [EC:3.6.1.75 3.1.3.4] | (RefSeq) DPP1, ZRG1; bifunctional diacylglycerol diphosphate phosphatase/phosphatidate phosphatase': 90.96,
#  'K12768 synaptonemal complex protein ZIP1 | (RefSeq) ZIP1; Zip1p': 6.48,
#  'no KO assigned | (RefSeq) MGP12; Mgp12p': 30.15,
#  'K01092 myo-inositol-1(or 4)-monophosphatase [EC:3.1.3.25] | (RefSeq) INM2; inositol monophosphate 1-phosphatase INM2': 31.08,
#  'K22823 non-structural maintenance of chromosomes element 3 | (RefSeq) NSE3; Smc5-Smc6 complex subunit NSE3': 46.27,
#  'K15559 regulator of Ty1 transposition protein 103 | (RefSeq) RTT103; Rtt103p': 35.13,
#  'no KO assigned | (RefSeq) SFT2; Sft2p': 96.74,
#  "K06877 DEAD/DEAH box helicase domain-containing protein | (RefSeq) HRQ1; ATP-dependent 3'-5' DNA helicase": 24.92,
#  'K13431 signal recognition particle receptor subunit alpha | (RefSeq) SRP101; Signal recognition particle receptor subunit alpha': 85.79,
#  'K18748 protein SSD1 | (RefSeq) SSD1, CLA1, MCS1, RLT1, SRK1; mRNA-binding translational repressor SSD1': 54.16,
#  'K01634 sphinganine-1-phosphate aldolase [EC:4.1.2.27] | (RefSeq) DPL1, BST1; sphinganine-1-phosphate aldolase DPL1': 81.68,
#  'no KO assigned | (RefSeq) HDA2, PLO2; Hda2p': 28.32,
#  'no KO assigned | (RefSeq) MHR1, mL67, XTC1; mitochondrial 54S ribosomal protein MHR1': 89.01,
#  'K04713 sphinganine C4-monooxygenase [EC:1.14.18.5] | (RefSeq) SUR2, SYR2; sphingosine hydroxylase': 244.84,
#  'K02137 F-type H+-transporting ATPase subunit O | (RefSeq) ATP5, OSC1; F1F0 ATP synthase subunit 5': 401.97,
#  'K14782 protein AATF/BFR2 | (RefSeq) BFR2; rRNA-processing protein BFR2': 119.11,
#  'K20060 arrestin-related trafficking adapter 2/8 | (RefSeq) ECM21, ART2; Ecm21p': 14.94,
#  'K00931 glutamate 5-kinase [EC:2.7.2.11] | (RefSeq) PRO1; glutamate 5-kinase': 114.55,
#  'K14401 cleavage and polyadenylation specificity factor subunit 1 | (RefSeq) CFT1, YHH1; cleavage/polyadenylation factor CFT1': 25.14,
#  'K05287 GPI ethanolamine phosphate transferase 2/3 subunit F | (RefSeq) GPI11; mannose-ethanolamine phosphotransferase GPI11': 58.16,
#  'K11758 chromatin structure-remodeling complex subunit RSC3/30 | (RefSeq) RSC3; Rsc3p': 52.38,
#  'K03768 peptidyl-prolyl cis-trans isomerase B (cyclophilin B) [EC:5.2.1.8] | (RefSeq) CPR5, CYP5; peptidylprolyl isomerase family protein CPR5': 280.67,
#  "K01522 bis(5'-adenosyl)-triphosphatase [EC:3.6.1.29] | (RefSeq) HNT2, APH1; bis(5'-adenosyl)-triphosphatase": 38.32,
#  'no KO assigned | (RefSeq) PFU1; Pfu1p': 30.46,
#  'K00728 dolichyl-phosphate-mannose-protein mannosyltransferase [EC:2.4.1.109] | (RefSeq) PMT7; putative dolichyl-phosphate-mannose--protein mannosyltransferase': 28.42,
#  'K15152 mediator of RNA polymerase II transcription subunit 21 | (RefSeq) SRB7, MED21, SSX1; Srb7p': 129.59,
#  'no KO assigned | (RefSeq) GIC2; Gic2p': 89.7,
#  'no KO assigned | (RefSeq) YBL101W-C; uncharacterized protein': 1.02,
#  'K12779 suppressor of MAR1-1 protein | (RefSeq) SUM1; Sum1p': 24.55,
#  'K03141 transcription initiation factor TFIIH subunit 1 | (RefSeq) TFB1; TFIIH/NER complex subunit TFB1': 32.08,
#  'K14859 ribosome biogenesis protein SSF1/2 | (RefSeq) SSF2; rRNA-binding ribosome biosynthesis protein': 62.11,
#  'no KO assigned | (RefSeq) PIB1; phosphatidylinositol-3-phosphate-binding ubiquitin-protein ligase': 30.1,
#  'no KO assigned | (RefSeq) RAD34; Rad34p': 13.44,
#  'K19786 inositol-pentakisphosphate 2-kinase [EC:2.7.1.158] | (RefSeq) IPK1, GSL1; inositol pentakisphosphate 2-kinase': 12.15,
#  'K17803 methyltransferase OMS1, mitochondrial [EC:2.1.1.-] | (RefSeq) OMS1; putative RNA methyltransferase': 35.76,
#  'no KO assigned | (RefSeq) HIM1; Him1p': 6.66,
#  'K11552 central kinetochore subunit Mal2/MCM21 | (RefSeq) MCM21, CTF5; Mcm21p': 25.84,
#  'K28100 fat storage-inducing transmembrane protein 2 [EC:3.6.1.-] | (RefSeq) YFT2, FIT2A; Yft2p': 39.82,
#  'no KO assigned | (RefSeq) SWA2, AUX1, BUD24; auxilin-like protein SWA2': 12.84,
#  'K11569 DASH complex subunit DAD4 | (RefSeq) DAD4, HSK2; Dad4p': 105.67,
#  'K01424 L-asparaginase [EC:3.5.1.1] | (RefSeq) ASP1; asparaginase ASP1': 198.41,
#  'K17439 large subunit ribosomal protein L35 | (RefSeq) MRPL35, mL38; mitochondrial 54S ribosomal protein YmL35': 75.13,
#  'K01549 F-type H+-transporting ATP synthase subunit e | (RefSeq) TIM11, ATP21; F1F0 ATP synthase subunit E': 289.44,
#  'K12481 rabenosyn-5 | (RefSeq) PEP7, VAC1, VPL21, VPS19, VPT19; phosphatidylinositol-3-phosphate binding protein': 15.08,
#  'K14548 U3 small nucleolar RNA-associated protein 4 | (RefSeq) UTP4; Utp4p': 141.16,
#  'K06678 condensin complex subunit 3 | (RefSeq) YCG1, TIE1, YCS5; condensin subunit YCG1': 20.09,
#  'K27898 protein Aster | (RefSeq) YSP2, LAM2, LTC4; Ysp2p': 33.58,
#  'K02132 F-type H+-transporting ATPase subunit alpha | (RefSeq) ATP1; F1F0 ATP synthase subunit alpha': 246.8,
#  'K03094 S-phase kinase-associated protein 1 | (RefSeq) SKP1, MGO1; SCF ubiquitin ligase subunit SKP1': 264.54,
#  'K13336 peroxin-3 | (RefSeq) PEX3, PAS3; Pex3p': 47.74,
#  'K24350 UBX domain-containing protein 7 | (RefSeq) UBX5; Ubx5p': 35.05,
#  'K05290 GPI-anchor transamidase subunit K | (RefSeq) GPI8; GPI-anchor transamidase': 62.26,
#  'K17677 ATP-dependent helicase IRC3 [EC:5.6.2.-] | (RefSeq) IRC3; double-stranded DNA-dependent ATPase': 18.78,
#  'K24970 transcription factor 25 | (RefSeq) RQC1; Rqc1p': 62.99,
#  'K11661 helicase SRCAP/SWR1 [EC:5.6.2.-] | (RefSeq) SWR1; chromatin-remodeling protein SWR1': 26.56,
#  'K14289 exportin-5 | (RefSeq) MSN5, KAP142, STE21; karyopherin MSN5': 37.45,
#  'no KO assigned | (RefSeq) MRX8; Mrx8p': 25.29,
#  'K00486 kynurenine 3-monooxygenase [EC:1.14.13.9] | (RefSeq) BNA4; kynurenine 3-monooxygenase': 109.02,
#  'K02956 small subunit ribosomal protein S15 | (RefSeq) MRPS28, uS15m; mitochondrial 37S ribosomal protein MRPS28': 80.8,
#  'K03327 MATE family, multidrug and toxin extrusion protein | (RefSeq) uncharacterized protein': 18.0,
#  'K14566 U3 small nucleolar RNA-associated protein 24 | (RefSeq) FCF1, UTP24; rRNA-processing protein FCF1': 168.65,
#  'K01887 arginyl-tRNA synthetase [EC:6.1.1.19] | (RefSeq) RRS1; arginine--tRNA ligase': 346.73,
#  'K08139 MFS transporter, SP family, sugar:H+ symporter | (RefSeq) HXT7; hexose transporter HXT7': 2.24,
#  'K08139 MFS transporter, SP family, sugar:H+ symporter | (RefSeq) HXT6; hexose transporter HXT6': 0.0,
#  'K08139 MFS transporter, SP family, sugar:H+ symporter | (RefSeq) HXT3; hexose transporter HXT3': 2363.04,
#  'no KO assigned | (RefSeq) SVF1, SGI1; Svf1p': 231.6,
#  'K06676 condensin complex subunit 2 | (RefSeq) BRN1; condensin subunit BRN1': 11.54,
#  'K04564 superoxide dismutase, Fe-Mn family [EC:1.15.1.1] | (RefSeq) MRP1, mS43; mitochondrial 37S ribosomal protein MRP1': 84.06,
#  'no KO assigned | (RefSeq) PAL1; Pal1p': 77.94,
#  'no KO assigned | (RefSeq) YPS7; putative aspartic endopeptidase': 85.06,
#  'K17673 mitochondrial translation factor ATP22 | (RefSeq) ATP22, TCM10; Atp22p': 32.29,
#  'no KO assigned | (RefSeq) SBE2; Sbe2p': 47.5,
#  'K23678 solute carrier family 66 (lysosomal lysine-arginine transporter), member 1 | (RefSeq) YPQ2; Ypq2p': 75.89,
#  'K00384 thioredoxin reductase (NADPH) [EC:1.8.1.9] | (RefSeq) TRR1; thioredoxin-disulfide reductase TRR1': 346.46,
#  'K00766 anthranilate phosphoribosyltransferase [EC:2.4.2.18] | (RefSeq) TRP4; anthranilate phosphoribosyltransferase': 101.08,
#  'no KO assigned | (RefSeq) SPC110, NUF1, XCM1; Spc110p': 29.12,
#  'K22240 biogenesis of lysosome-related organelles complex 1 subunit CNL1 | (RefSeq) CNL1; Cnl1p': 98.3,
#  'K12404 ADP-ribosylation factor-binding protein GGA | (RefSeq) GGA1; ubiquitin-binding protein': 18.7,
#  'K11397 chromatin modification-related protein VID21 | (RefSeq) EAF1, VID21; Eaf1p': 19.0,
#  'K15262 protein BCP1 | (RefSeq) BCP1; protein-transporting protein BCP1': 189.75,
#  'K15205 transcription factor C subunit 6 | (RefSeq) TFC6; transcription factor TFIIIC subunit TFC6': 25.96,
#  'no KO assigned | (RefSeq) ESC2; Esc2p': 51.52,
#  'K10881 26 proteasome complex subunit DSS1 | (RefSeq) SEM1, DSS1, HOD1; proteasome regulatory particle lid subunit SEM1': 313.86,
#  'K12816 pre-mRNA-processing factor 17 | (RefSeq) CDC40, PRP17, SLT15, SLU4; Cdc40p': 46.9,
#  'no KO assigned | (RefSeq) MRX3; Mrx3p': 23.96,
#  'K00262 glutamate dehydrogenase (NADP+) [EC:1.4.1.4] | (RefSeq) GDH3, FUN51; glutamate dehydrogenase (NADP(+)) GDH3': 6.71,
#  'no KO assigned | (RefSeq) ESF1; pre-rRNA-processing protein ESF1': 184.29,
#  'no KO assigned | (RefSeq) MOR1; Mor1p': 5.86,
#  'K22724 inositol phosphorylceramide synthase regulatory subunit | (RefSeq) KEI1; Kei1p': 113.4,
#  'no KO assigned | (RefSeq) YPR1; trifunctional aldehyde reductase/carbonyl reductase (NADPH)/glucose 1-dehydrogenase (NADP(+)) YPR1': 93.86,
#  'K10868 DNA repair protein XRS2 | (RefSeq) XRS2; Xrs2p': 11.04,
#  'no KO assigned | (RefSeq) DXO1; Dxo1p': 38.04,
#  'K01183 chitinase [EC:3.2.1.14] | (RefSeq) CTS2; putative chitinase': 18.96,
#  'K15620 golgi phosphoprotein 3 | (RefSeq) VPS74, API1, MNN3; Vps74p': 186.95,
#  'K19932 neuronal calcium sensor | (RefSeq) FRQ1; frequenin': 101.76,
#  'K20102 YTH domain-containing family protein | (RefSeq) PHO92, MRB1; mRNA-binding phosphate metabolism regulator': 0.51,
#  'no KO assigned | (RefSeq) WIP1; Wip1p': 76.6,
#  'K08900 mitochondrial chaperone BCS1 | (RefSeq) BCS1; bifunctional AAA family ATPase chaperone/translocase BCS1': 35.12,
#  'K18914 adrenodoxin-NADP+ reductase [EC:1.18.1.6] | (RefSeq) ARH1; NADPH-adrenodoxin reductase': 33.22,
#  'K02139 F-type H+-transporting ATPase subunit f | (RefSeq) ATP17; F1F0 ATP synthase subunit F': 525.11,
#  'K12625 U6 snRNA-associated Sm-like protein LSm6 | (RefSeq) LSM6; U4/U6-U5 snRNP complex subunit LSM6': 337.97,
#  'K19839 Rho-type GTPase-activating protein 1/2 | (RefSeq) RGA2; GTPase-activating protein RGA2': 25.17,
#  'K18167 succinate dehydrogenase assembly factor 1 | (RefSeq) SDH6; Sdh6p': 23.16,
#  'K12732 phenylpyruvate decarboxylase [EC:4.1.1.-] | (RefSeq) ARO10; phenylpyruvate decarboxylase ARO10': 2.22,
#  'K12881 THO complex subunit 4 | (RefSeq) YRA1, SHE11; RNA-binding protein YRA1': 578.18,
#  'K15138 mediator of RNA polymerase II transcription subunit 19, fungi type | (RefSeq) ROX3, MED19, NUT3, RMR1, SSN7, SSX2; Rox3p': 138.17,
#  'no KO assigned | (RefSeq) COI1, MCO13; Coi1p': 61.09,
#  'K02943 large subunit ribosomal protein LP2 | (RefSeq) RPP2B, RPL45, YPA1; ribosomal protein P2B': 4189.33,
#  'no KO assigned | (RefSeq) NKP1; Nkp1p': 29.26,
#  'K07034 acetate uptake transporter family protein | (RefSeq) ATO3; putative ammonium permease ATO3': 42.09,
#  'K03234 elongation factor 2 | (RefSeq) EFT2; elongation factor 2': 659.98,
#  'K08991 crossover junction endonuclease MUS81 [EC:3.1.22.-] | (RefSeq) MUS81, SLX3; Mus81p': 15.85,
#  'K08150 MFS transporter, SP family, solute carrier family 2 (myo-inositol transporter), member 13 | (RefSeq) CIN10; Cin10p': 24.41,
#  'K12562 amphiphysin | (RefSeq) RVS167; amphiphysin': 105.16,
#  'K19845 GTPase-activating protein SAC7 | (RefSeq) SAC7; GTPase-activating protein SAC7': 51.4,
#  'K10685 ubiquitin-like 1-activating enzyme E1 B [EC:6.2.1.45] | (RefSeq) UBA2, UAL1; E1 ubiquitin-activating protein UBA2': 58.59,
#  'K02912 large subunit ribosomal protein L32e | (RefSeq) RPL32; ribosomal 60S subunit protein L32': 4524.02,
#  'K11313 transcription initiation protein SPT3 | (RefSeq) SPT3; transcriptional regulator SPT3': 37.28,
#  'K17983 sensitive to high expression protein 9, mitochondrial | (RefSeq) SHE9, MDM33; She9p': 24.16,
#  'K03063 26S proteasome regulatory subunit T3 | (RefSeq) RPT3, YNT1, YTA2; proteasome regulatory particle base subunit RPT3': 176.81,
#  'K20223 importin-7 | (RefSeq) SXM1, KAP108; Sxm1p': 123.8,
#  'K21751 down-regulator of transcription 1 | (RefSeq) NCB2, YDR1; negative cofactor 2 transcription regulator complex subunit NCB2': 218.09,
#  'K14546 U3 small nucleolar RNA-associated protein 5 | (RefSeq) UTP5; Utp5p': 125.35,
#  'K19836 hypoxanthine phosphoribosyltransferase [EC:2.4.2.8] | (RefSeq) HPT1, BRA6; hypoxanthine phosphoribosyltransferase': 1007.23,
#  'K01240 uridine nucleosidase [EC:3.2.2.3] | (RefSeq) URH1; trifunctional uridine nucleosidase/nicotinamide riboside hydrolase/nicotinic acid riboside hydrolase': 51.97,
#  'no KO assigned | (RefSeq) SCS22; phospholipid metabolism-regulating protein SCS22': 24.92,
#  'no KO assigned | (RefSeq) DIT2, CYP56; putative cytochrome P450': 1.22,
#  'no KO assigned | (RefSeq) DIT1; Dit1p': 5.25,
#  'K03015 DNA-directed RNA polymerase II subunit RPB7 | (RefSeq) RPB7; DNA-directed RNA polymerase II subunit RPB7': 168.28,
#  'K02892 large subunit ribosomal protein L23 | (RefSeq) MRP20, uL23m; mitochondrial 54S ribosomal protein YmL41': 18.51,
#  'K08711 ATP-binding cassette, subfamily G (WHITE), member 2, PDR | (RefSeq) PDR15; ATP-binding cassette multidrug transporter PDR15': 7.98,
#  'K20306 trafficking protein particle complex subunit 9 | (RefSeq) TRS120; Trs120p': 26.31,
#  'K00601 phosphoribosylglycinamide formyltransferase [EC:2.1.2.2] | (RefSeq) ADE8; phosphoribosylglycinamide formyltransferase': 338.41,
#  'K04706 E3 SUMO-protein ligase PIAS1 [EC:2.3.2.-] | (RefSeq) SIZ1, ULL1; SUMO ligase SIZ1': 17.87,
#  'K01265 methionyl aminopeptidase [EC:3.4.11.18] | (RefSeq) MAP2; methionine aminopeptidase': 110.55,
#  'K00587 protein-S-isoprenylcysteine O-methyltransferase [EC:2.1.1.100] | (RefSeq) STE14; protein-S-isoprenylcysteine carboxyl O-methyltransferase': 65.54,
#  'K13989 Derlin-2/3 | (RefSeq) DFM1; Dfm1p': 32.24,
#  'K14851 ribosomal RNA-processing protein 17 | (RefSeq) RRP17; Rrp17p': 190.1,
#  'no KO assigned | (RefSeq) ERD1, LDB2; Erd1p': 27.32,
#  'no KO assigned | (RefSeq) putative aminopeptidase': 36.75,
#  'K12867 pre-mRNA-splicing factor SYF1 | (RefSeq) SYF1, NTC90; mRNA splicing protein SYF1': 26.15,
#  'K02870 large subunit ribosomal protein L12e | (RefSeq) RPL12B; ribosomal 60S subunit protein L12B': 2481.26,
#  'K03509 DNA polymerase eta [EC:2.7.7.7] | (RefSeq) RAD30, DBH1; DNA-directed DNA polymerase eta': 25.01,
#  'K17415 small subunit ribosomal protein MRP21 | (RefSeq) MRP21, bS21m, MRP50; mitochondrial 37S ribosomal protein MRP21': 77.69,
#  'K19848 signaling mucin HKR1 | (RefSeq) HKR1; Hkr1p': 12.38,
#  'no KO assigned | (RefSeq) ARO80; Aro80p': 13.14,
#  'no KO assigned | (RefSeq) SIP1; Sip1p': 28.85,
#  'K09043 AP-1-like transcription factor | (RefSeq) CAD1, YAP2; Cad1p': 28.83,
#  'K10418 dynein light chain LC8-type | (RefSeq) DYN2, SLC1; dynein light chain': 99.25,
#  'K21996 sorting nexin-41/42 | (RefSeq) SNX41; Snx41p': 12.22,
#  'K03039 26S proteasome regulatory subunit N9 | (RefSeq) RPN9, NAS7; proteasome regulatory particle lid subunit RPN9': 154.83,
#  'K14263 kynurenine formamidase [EC:3.5.1.9] | (RefSeq) BNA7; arylformamidase': 53.85,
#  'K03248 translation initiation factor 3 subunit G | (RefSeq) TIF35; translation initiation factor eIF3 core subunit G': 482.89,
#  'no KO assigned | (RefSeq) AVT5; amino acid transporter': 23.02,
#  'K06972 presequence protease [EC:3.4.24.-] | (RefSeq) CYM1, MOP112; pitrilysin family metalloprotease': 23.99,
#  'K14651 transcription initiation factor TFIID subunit 15 | (RefSeq) NPL3, MTR13, MTS1, NAB1, NOP3; mRNA-binding protein NPL3': 230.49,
#  'K05291 GPI-anchor transamidase subunit S | (RefSeq) GPI17; GPI-anchor transamidase GPI17': 68.67,
#  'K18203 [phosphatase 2A protein]-leucine-carboxy methyltransferase [EC:2.1.1.233] | (RefSeq) PPM1; leucine carboxy methyltransferase': 29.33,
#  'K06269 serine/threonine-protein phosphatase PP1 catalytic subunit [EC:3.1.3.16] | (RefSeq) PPZ2; salt homeostasis regulator': 7.01,
#  'K03861 phosphatidylinositol N-acetylglucosaminyltransferase subunit P | (RefSeq) GPI19; phosphatidylinositol N-acetylglucosaminyltransferase GPI19': 25.23,
#  'K15289 solute carrier family 35, member F5 | (RefSeq) THI74; Thi74p': 16.66,
#  'K12775 monopolin complex subunit LRS4 | (RefSeq) LRS4; Lrs4p': 31.47,
#  'K04728 serine-protein kinase ATM [EC:2.7.11.1] | (RefSeq) TEL1; DNA-binding protein kinase TEL1': 13.93,
#  'K11427 [histone H3]-lysine79 N-trimethyltransferase [EC:2.1.1.360] | (RefSeq) DOT1, KMT4, PCH1; histone methyltransferase DOT1': 33.62,
#  'K00759 adenine phosphoribosyltransferase [EC:2.4.2.7] | (RefSeq) APT2; adenine phosphoribosyltransferase APT2': 100.66,
#  'K15165 mediator of RNA polymerase II transcription subunit 13, fungi type | (RefSeq) SSN2, MED13, NUT8, RYE3, SCA1, SRB9, SSX5, UME2; Ssn2p': 12.04,
#  'no KO assigned | (RefSeq) putative hydrolase': 31.16,
#  'no KO assigned | (RefSeq) ECM11; Ecm11p': 0.38,
#  'K02962 small subunit ribosomal protein S17e | (RefSeq) RPS17B, RP51B, RPL51B; ribosomal 40S subunit protein S17B': 2043.76,
#  'K11314 transcriptional adapter 2-alpha | (RefSeq) ADA2, SWI8; chromatin-binding transcription regulator ADA2': 26.68,
#  'K14557 U3 small nucleolar RNA-associated protein 6 | (RefSeq) UTP6; snoRNA-binding rRNA-processing protein UTP6': 104.95,
#  'K02894 large subunit ribosomal protein L23e | (RefSeq) RPL23A; ribosomal 60S subunit protein L23A': 1667.43,
#  'K02964 small subunit ribosomal protein S18e | (RefSeq) RPS18A; ribosomal 40S subunit protein S18A': 3093.22,
#  'K12411 homeobox protein YOX1/YHP1 | (RefSeq) YHP1; Yhp1p': 52.84,
#  'K06018 endopolyphosphatase [EC:3.6.1.10] | (RefSeq) PPN1, PHM5; endopolyphosphatase': 71.69,
#  'K03386 peroxiredoxin 2/4 [EC:1.11.1.24] | (RefSeq) TSA2; thioredoxin peroxidase TSA2': 11.57,
#  'K00942 guanylate kinase [EC:2.7.4.8] | (RefSeq) GUK1, BRA3, PUR5; guanylate kinase': 543.38,
#  'K12041 solute carrier family 9 (sodium/hydrogen exchanger), member 6/7 | (RefSeq) NHX1, NHA2, VPL27, VPS44; bifunctional K:H/Na:H antiporter NHX1': 50.55,
#  'K10592 E3 ubiquitin-protein ligase HUWE1 [EC:2.3.2.26] | (RefSeq) TOM1; E3 ubiquitin-protein ligase TOM1': 28.87,
#  'no KO assigned | (RefSeq) HEH2; Heh2p': 46.27,
#  'K18932 palmitoyltransferase [EC:2.3.1.225] | (RefSeq) PFA5; palmitoyltransferase PFA5': 34.21,
#  'K00004 (R,R)-butanediol dehydrogenase / meso-butanediol dehydrogenase / diacetyl reductase [EC:1.1.1.4 1.1.1.- 1.1.1.303] | (RefSeq) BDH2; putative dehydrogenase BDH2': 5.04,
#  'K10842 CDK-activating kinase assembly factor MAT1 | (RefSeq) TFB3, RIG2; TFIIH/NER complex subunit TFB3': 44.09,
#  'K11235 mating pheromone A-factor | (RefSeq) MFA1; mating pheromone A': 701.64,
#  'no KO assigned | (RefSeq) CMI8; Cmi8p': 24.19,
#  'K17421 large subunit ribosomal protein L40 | (RefSeq) MRPL28, mL40; mitochondrial 54S ribosomal protein YmL28': 65.91,
#  'no KO assigned | (RefSeq) STP1, BAP1, SSY2; Stp1p': 48.74,
#  'no KO assigned | (RefSeq) SPP41; Spp41p': 17.61,
#  'K18477 type IV protein arginine methyltransferase [EC:2.1.1.322] | (RefSeq) RMT2; protein-arginine N5-methyltransferase': 150.03,
#  'K06276 3-phosphoinositide dependent protein kinase-1 [EC:2.7.11.1] | (RefSeq) PKH3; protein kinase PKH3': 23.99,
#  'no KO assigned | (RefSeq) BOI1, BOB1, GIN7; Boi1p': 39.42,
#  'K08499 member of the syntaxin family of t-SNAREs | (RefSeq) TLG1; Tlg1p': 104.2,
#  'K14968 COMPASS component SDC1 | (RefSeq) SDC1, CPS25, SAF19; Sdc1p': 89.89,
#  'K17967 mitochondrial fusion and transport protein UGO1 | (RefSeq) UGO1; Ugo1p': 22.69,
#  'K02901 large subunit ribosomal protein L27e | (RefSeq) RPL27B; ribosomal 60S subunit protein L27B': 1890.64,
#  'K20280 trafficking protein particle complex subunit 5 | (RefSeq) TRS31; TRAPP subunit TRS31': 70.25,
#  'K12843 U4/U6 small nuclear ribonucleoprotein PRP3 | (RefSeq) PRP3, RNA3; U4/U6-U5 snRNP complex subunit PRP3': 30.92,
#  'no KO assigned | (RefSeq) JIP4, YDR474C; Jip4p': 16.88,
#  'K12761 carbon catabolite-derepressing protein kinase [EC:2.7.11.1] | (RefSeq) SNF1, CAT1, CCR1, GLC2, HAF3, PAS14; AMP-activated serine/threonine-protein kinase catalytic subunit SNF1': 55.01,
#  'K14531 ribonuclease MRP protein subunit SNM1 | (RefSeq) SNM1; Snm1p': 36.54,
#  'K03350 anaphase-promoting complex subunit 3 | (RefSeq) CDC27, APC3, SNB1; anaphase promoting complex subunit CDC27': 19.58,
#  'no KO assigned | (RefSeq) PEX29; Pex29p': 17.58,
#  'K11242 down-regulator of invasive growth 2 | (RefSeq) DIG2, RST2; Dig2p': 22.57,
#  'K01077 alkaline phosphatase [EC:3.1.3.1] | (RefSeq) PHO8; alkaline phosphatase PHO8': 67.91,
#  'no KO assigned | (RefSeq) CWC21; U2-type spliceosomal complex subunit CWC21': 79.38,
#  'K10967 alpha 1,2-mannosyltransferase [EC:2.4.1.-] | (RefSeq) KRE2, MNT1; alpha-1,2-mannosyltransferase KRE2': 321.91,
#  'K20298 vacuolar protein sorting-associated protein 52 | (RefSeq) VPS52, SAC2; Vps52p': 22.1,
#  'K11664 vacuolar protein sorting-associated protein 72 | (RefSeq) VPS72, SWC2; Vps72p': 27.01,
#  'K12198 charged multivesicular body protein 5 | (RefSeq) VPS60, CHM5, MOS10; Vps60p': 72.88,
#  'K02858 3,4-dihydroxy 2-butanone 4-phosphate synthase [EC:4.1.99.12] | (RefSeq) RIB3; 3,4-dihydroxy-2-butanone-4-phosphate synthase RIB3': 264.31,
#  'K10415 dynein cytoplasmic 1 intermediate chain | (RefSeq) PAC11; dynein intermediate chain': 14.48,
#  'K10735 GINS complex subunit 4 | (RefSeq) SLD5, CDC105; DNA replication protein SLD5': 32.18,
#  'K06276 3-phosphoinositide dependent protein kinase-1 [EC:2.7.11.1] | (RefSeq) PKH1; serine/threonine protein kinase PKH1': 13.56,
#  'K07297 adiponectin receptor | (RefSeq) IZH1; PAQR-type receptor': 258.93,
#  'K18170 complex III assembly factor LYRM7 | (RefSeq) MZM1, AIM8, FMP36; Mzm1p': 66.11,
#  'no KO assigned | (RefSeq) RSM28, mS46; mitochondrial 37S ribosomal protein RSM28': 68.59,
#  'K20177 vacuolar protein sorting-associated protein 3 | (RefSeq) VPS3, PEP6, VPL3, VPT17; CORVET complex subunit VPS3': 16.6,
#  'K14844 pumilio homology domain family member 6 | (RefSeq) PUF6; Puf6p': 222.82,
#  'K08150 MFS transporter, SP family, solute carrier family 2 (myo-inositol transporter), member 13 | (RefSeq) ITR1; myo-inositol transporter ITR1': 1130.99,
#  'K08497 protein transport protein SEC20 | (RefSeq) SEC20; Sec20p': 34.43,
# ...
#  'K14642 golgi apyrase [EC:3.6.1.5] | (RefSeq) YND1, APY1, YEJ5; apyrase': 51.65,
#  'K14538 nuclear GTP-binding protein | (RefSeq) NUG1; RNA-binding GTPase NUG1': 272.26,
#  'K21768 tubulin-specific chaperone E | (RefSeq) PAC2; Pac2p': 13.43,
#  'K07575 malignant T-cell-amplified sequence | (RefSeq) TMA20; translation machinery-associated protein 20': 246.91,
#  'K19983 exocyst complex component 1 | (RefSeq) SEC3, PSL1; GTP-Rho binding exocyst subunit SEC3': 25.37,
#  'no KO assigned | (RefSeq) NTF2; Ran GTPase-binding protein NTF2': 951.67,
#  'no KO assigned | (RefSeq) bifunctional 4-hydroxy-4-methyl-2-oxoglutarate aldolase/oxaloacetate decarboxylase': 44.44,
#  'no KO assigned | (RefSeq) TIR1, SRP1; GPI-anchored mannoprotein': 1.22,
#  'K02734 20S proteasome subunit beta 4 [EC:3.4.25.1] | (RefSeq) PRE1; proteasome core particle subunit beta 4': 278.79,
#  'no KO assigned | (RefSeq) PSY4, HSM6; Psy4p': 36.96,
#  'K12818 ATP-dependent RNA helicase DHX8/PRP22 [EC:5.6.2.6] | (RefSeq) PRP22; DEAH-box ATP-dependent RNA helicase PRP22': 15.75,
#  'K00231 protoporphyrinogen/coproporphyrinogen III oxidase [EC:1.3.3.4 1.3.3.15] | (RefSeq) HEM14; oxygen-dependent protoporphyrinogen oxidase': 20.98,
#  'no KO assigned | (RefSeq) BUD25; Bud25p': 0.16,
#  'K01897 long-chain-fatty-acid---CoA ligase [EC:6.2.1.3] | (RefSeq) FAA2, FAM1; medium-chain fatty acid-CoA ligase FAA2': 10.01,
#  'K10436 microtubule-associated protein, RP/EB family | (RefSeq) BIM1, YEB1; microtubule-binding protein BIM1': 67.69,
#  'K08956 AFG3 family protein [EC:3.4.24.-] | (RefSeq) AFG3, YTA10; AAA family ATPase AFG3': 46.62,
#  'K11558 kinetochore protein Spc25, fungi type | (RefSeq) SPC25; kinetochore-associated Ndc80 complex subunit SPC25': 28.69,
#  'K12351 sphingomyelin phosphodiesterase 2 [EC:3.1.4.12] | (RefSeq) ISC1; inositol phosphosphingolipid phospholipase': 38.6,
#  'K09481 protein transport protein SEC61 subunit beta | (RefSeq) SBH2, SEB2; Arf family guanine nucleotide exchange factor SBH2': 415.11,
#  'K04630 guanine nucleotide-binding protein G(i) subunit alpha | (RefSeq) GPA2, SSP101; guanine nucleotide-binding protein subunit alpha': 60.75,
#  'K00414 ubiquinol-cytochrome c reductase core subunit 1 | (RefSeq) COR1, QCR1; ubiquinol--cytochrome-c reductase subunit COR1': 268.45,
#  'K03033 26S proteasome regulatory subunit N3 | (RefSeq) RPN3, SUN2; proteasome regulatory particle lid subunit RPN3': 187.33,
#  'K15134 mediator of RNA polymerase II transcription subunit 17, fungi type | (RefSeq) SRB4, MED17; Srb4p': 33.08,
#  'K00286 pyrroline-5-carboxylate reductase [EC:1.5.1.2] | (RefSeq) PRO3, ORE2; pyrroline-5-carboxylate reductase': 233.38,
#  'K00624 carnitine O-acetyltransferase [EC:2.3.1.7] | (RefSeq) YAT2; carnitine O-acetyltransferase YAT2': 16.36,
#  'K03242 translation initiation factor 2 subunit 3 | (RefSeq) GCD11, SUI4; translation initiation factor eIF2 subunit gamma': 417.35,
#  'K17103 CDP-diacylglycerol---serine O-phosphatidyltransferase [EC:2.7.8.8] | (RefSeq) CHO1, PSS1; CDP-diacylglycerol-serine O-phosphatidyltransferase': 447.98,
#  'no KO assigned | (RefSeq) GAL83, SPM1; Gal83p': 47.3,
#  'K09467 zinc-finger protein CreA/MIG | (RefSeq) MIG3; Mig3p': 12.62,
#  "K11086 small nuclear ribonucleoprotein B and B' | (RefSeq) SMB1; mRNA splicing protein SMB1": 62.12,
#  'no KO assigned | (RefSeq) CHZ1; Chz1p': 177.63,
#  'K07905 Ras-related protein Rab-11B | (RefSeq) YPT31, YPT8; Rab family GTPase YPT31': 220.67,
#  'no KO assigned | (RefSeq) FIR1, PIP1; Fir1p': 15.73,
#  'no KO assigned | (RefSeq) ZRG8; Zrg8p': 7.09,
#  'K18759 enhancer of mRNA-decapping protein 1/2 | (RefSeq) EDC2; Edc2p': 67.94,
#  'K06185 ATP-binding cassette, subfamily F, member 2 | (RefSeq) ARB1; ATP-binding cassette family ATPase ARB1': 423.79,
#  'K23736 2-lysophosphatidate phosphatase [EC:3.1.3.106] | (RefSeq) PHM8; bifunctional nucleotidase/lysophosphatidic acid phosphatase': 25.36,
#  'K28410 DNA repair protein KRE29 | (RefSeq) KRE29, NSE6; Smc5-Smc6 complex subunit KRE29': 23.71,
#  'no KO assigned | (RefSeq) FMP49; Fmp49p': 7.29,
#  'no KO assigned | (RefSeq) ECM13; Ecm13p': 26.91,
#  'K15356 GDP-mannose transporter | (RefSeq) HVG1, YEM9; putative GDP-mannose transporter': 7.97,
#  'K09184 GATA-binding protein, other eukaryote | (RefSeq) GLN3; nitrogen-responsive transcriptional regulator GLN3': 17.13,
#  'K15338 holliday junction resolvase GEN1/YEN1 [EC:3.1.-.-] | (RefSeq) YEN1; crossover junction endodeoxyribonuclease': 14.37,
#  'K07304 peptide-methionine (S)-S-oxide reductase [EC:1.8.4.11] | (RefSeq) MXR1; peptide-methionine-S-sulfoxide reductase': 97.26,
#  'K01251 adenosylhomocysteinase [EC:3.13.2.1] | (RefSeq) SAH1; adenosylhomocysteinase': 1834.08,
#  'no KO assigned | (RefSeq) ERG28, BUD18; Erg28p': 422.35,
#  'no KO assigned | (RefSeq) MEI4; Mei4p': 4.43,
#  'no KO assigned | (RefSeq) ACA1; Aca1p': 29.19,
#  'no KO assigned | (RefSeq) SPO73; Spo73p': 24.99,
#  'K03457 nucleobase:cation symporter-1, NCS1 family | (RefSeq) FUI1; uridine permease': 261.71,
#  'K22766 fidgetin-like protein 1 [EC:5.6.2.-] | (RefSeq) SAP1; putative AAA family ATPase SAP1': 13.2,
#  'no KO assigned | (RefSeq) CAJ1; Caj1p': 161.06,
#  'K22069 LYR motif-containing protein 4 | (RefSeq) ISD11; Isd11p': 277.07,
#  'K24029 prolyl 3-hydroxylase /prolyl 3,4-dihydroxylase [EC:1.14.11.-] | (RefSeq) TPA1; oxidative DNA demethylase': 187.2,
#  'K02963 small subunit ribosomal protein S18 | (RefSeq) RSM18, bS18m; mitochondrial 37S ribosomal protein RSM18': 133.57,
#  'K10276 F-box and leucine-rich repeat protein 10/11 [EC:1.14.11.27] | (RefSeq) JHD1, KDM2; [Histone H3]-lysine-36 demethylase': 22.01,
#  'K00928 aspartate kinase [EC:2.7.2.4] | (RefSeq) HOM3, BOR1, SIL4, THR3; aspartate kinase': 215.02,
#  'K15102 solute carrier family 25 (mitochondrial phosphate transporter), member 3 | (RefSeq) PIC2; Cu/Pi carrier': 41.64,
#  'K02732 20S proteasome subunit beta 6 [EC:3.4.25.1] | (RefSeq) PRE7, PRS3; proteasome core particle subunit beta 6': 284.57,
#  'no KO assigned | (RefSeq) GIP2; Gip2p': 2.76,
#  'K00765 ATP phosphoribosyltransferase [EC:2.4.2.17] | (RefSeq) HIS1; ATP phosphoribosyltransferase': 848.56,
#  'no KO assigned | (RefSeq) FCY2, BRA7; purine-cytosine permease': 613.43,
#  'K02915 large subunit ribosomal protein L34e | (RefSeq) RPL34A; ribosomal 60S subunit protein L34A': 2261.51,
#  'no KO assigned | (RefSeq) HMF1, HIG1; putative isoleucine biosynthesis protein HMF1': 286.46,
#  'K18188 protein PET117 | (RefSeq) PET117; Pet117p': 22.92,
#  'K24113 PHO85 cyclin-6/7 | (RefSeq) PCL6; Pcl6p': 40.25,
#  'no KO assigned | (RefSeq) FCY21; purine-cytosine permease': 7.89,
#  'no KO assigned | (RefSeq) FCY22; purine-cytosine permease': 0.66,
#  'K09458 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] | (RefSeq) CEM1; fatty acid synthase CEM1': 77.14,
#  'K10949 ER lumen protein retaining receptor | (RefSeq) ERD2; Erd2p': 154.15,
#  'K06116 glycerol-1-phosphatase [EC:3.1.3.21] | (RefSeq) GPP2, HOR2; glycerol-1-phosphatase GPP2': 263.95,
#  'K18732 SAP domain-containing ribonucleoprotein | (RefSeq) THO1; Tho1p': 171.58,
#  'no KO assigned | (RefSeq) VHR2; Vhr2p': 79.51,
#  'K01637 isocitrate/methylisocitrate lyase [EC:4.1.3.1 4.1.3.30] | (RefSeq) ICL1; isocitrate lyase 1': 27.46,
#  'no KO assigned | (RefSeq) RRT13; Rrt13p': 8.2,
#  'no KO assigned | (RefSeq) RGI1; Rgi1p': 17.0,
#  'K10643 CCR4-NOT transcription complex subunit 4 [EC:2.3.2.27] | (RefSeq) MOT2, NOT4, SIG1; CCR4-NOT core ubiquitin-protein ligase subunit MOT2': 33.37,
#  'no KO assigned | (RefSeq) MIN6, YBL039W-A; Min6p': 23.91,
#  'K12659 N-acetyl-gamma-glutamyl-phosphate reductase / acetylglutamate kinase [EC:1.2.1.38 2.7.2.8] | (RefSeq) ARG56; bifunctional acetylglutamate kinase/N-acetyl-gamma-glutamyl-phosphate reductase': 237.54,
#  'K10807 ribonucleoside-diphosphate reductase subunit M1 [EC:1.17.4.1] | (RefSeq) RNR1, CRT7, RIR1, SDS12; ribonucleotide-diphosphate reductase subunit RNR1': 161.24,
#  'no KO assigned | (RefSeq) TDA2; Tda2p': 65.45,
#  'K27690 vacuolar transporter chaperone complex subunit 1 | (RefSeq) VTC1, NRF1, PHM4; Vtc1p': 435.28,
#  'K00128 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] | (RefSeq) ALD5; aldehyde dehydrogenase (NAD(P)(+)) ALD5': 346.14,
#  'K02974 small subunit ribosomal protein S24e | (RefSeq) RPS24A, RPS24EA; ribosomal 40S subunit protein S24A': 2869.47,
#  'K22939 immediate early response 3-interacting protein 1 | (RefSeq) YOS1; Yos1p': 161.47,
#  'K19806 tyrosine-protein phosphatase 2/3 [EC:3.1.3.48] | (RefSeq) PTP3; tyrosine protein phosphatase PTP3': 16.47,
#  'K01937 CTP synthase [EC:6.3.4.2] | (RefSeq) URA7; CTP synthase URA7': 293.26,
#  'no KO assigned | (RefSeq) MRX1; Mrx1p': 27.95,
#  'K18573 intermediate cleaving peptidase 55 [EC:3.4.11.26] | (RefSeq) ICP55; aminopeptidase': 32.76,
#  'no KO assigned | (RefSeq) AIM9, FMP29; Aim9p': 53.47,
#  'K00058 D-3-phosphoglycerate dehydrogenase / 2-oxoglutarate reductase [EC:1.1.1.95 1.1.1.399] | (RefSeq) SER3; phosphoglycerate dehydrogenase SER3': 68.79,
#  'K14768 U3 small nucleolar RNA-associated protein 7 | (RefSeq) UTP7, KRE31; Utp7p': 131.01,
#  'K22386 GET complex subunit GET2 | (RefSeq) GET2, HUR2, RMD7; GET complex subunit GET2': 45.8,
#  'K01754 threonine dehydratase [EC:4.3.1.19] | (RefSeq) ILV1, ISO1; threonine ammonia-lyase ILV1': 318.9,
#  'K01881 prolyl-tRNA synthetase [EC:6.1.1.15] | (RefSeq) AIM10; putative proline--tRNA ligase AIM10': 18.88,
#  'K09481 protein transport protein SEC61 subunit beta | (RefSeq) SBH1, SEB1, YER087C-A; Arf family guanine nucleotide exchange factor SBH1': 504.97,
#  'no KO assigned | (RefSeq) DOT6, PBF2; Dot6p': 69.43,
#  'K14803 protein phosphatase PTC2/3 [EC:3.1.3.16] | (RefSeq) PTC2; type 2C protein phosphatase PTC2': 31.94,
#  'no KO assigned | (RefSeq) MRPL16, RML16, uL16m; mitochondrial 54S ribosomal protein YmL47': 90.06,
#  'K01657 anthranilate synthase component I [EC:4.1.3.27] | (RefSeq) TRP2; anthranilate synthase TRP2': 171.24,
#  'K00549 5-methyltetrahydropteroyltriglutamate--homocysteine methyltransferase [EC:2.1.1.14] | (RefSeq) MET6; 5-methyltetrahydropteroyltriglutamate-homocysteine S-methyltransferase': 1078.81,
#  'K11679 Ino eighty subunit 5 | (RefSeq) IES5; Ies5p': 114.76,
#  'K08267 rapamycin-insensitive companion of mTOR | (RefSeq) TSC11, AVO3; TORC2 complex subunit TSC11': 12.03,
#  'no KO assigned | (RefSeq) AIM11, GEP8; Aim11p': 23.17,
#  'K02735 20S proteasome subunit beta 3 [EC:3.4.25.1] | (RefSeq) PUP3, SCS32; proteasome core particle subunit beta 3': 283.96,
#  'K04482 DNA repair protein RAD51 | (RefSeq) RAD51, MUT5; recombinase RAD51': 63.45,
#  'K07126 uncharacterized protein | (RefSeq) SHC1; Shc1p': 3.56,
#  'K11824 AP-2 complex subunit alpha | (RefSeq) APL3; Apl3p': 16.22,
#  'K11872 ubiquitin carboxyl-terminal hydrolase 9/13 [EC:3.4.19.12] | (RefSeq) UBP9; putative ubiquitin-specific protease UBP9': 8.38,
#  'K00948 ribose-phosphate pyrophosphokinase [EC:2.7.6.1] | (RefSeq) PRS2; ribose phosphate diphosphokinase subunit PRS2': 75.5,
#  'K04554 ubiquitin-conjugating enzyme E2 J2 [EC:2.3.2.23] | (RefSeq) UBC6, DOA2; E2 ubiquitin-conjugating protein UBC6': 138.83,
#  'no KO assigned | (RefSeq) AST2; Ast2p': 16.3,
#  'K02995 small subunit ribosomal protein S8e | (RefSeq) RPS8B; ribosomal 40S subunit protein S8B': 2568.44,
#  'K03283 heat shock 70kDa protein 1/6/8 | (RefSeq) SSA4, YG107; Hsp70 family chaperone SSA4': 25.14,
#  'no KO assigned | (RefSeq) RTT105; Rtt105p': 30.12,
#  'K14312 nuclear pore complex protein Nup155 | (RefSeq) NUP157; Nup157p': 45.83,
#  'K12774 monopolin complex subunit MAM1 | (RefSeq) MAM1; Mam1p': 2.79,
#  'K06997 PLP dependent protein | (RefSeq) uncharacterized protein': 154.0,
#  'K14298 mRNA export factor | (RefSeq) GLE2, RAE1; RNA export factor GLE2': 91.25,
#  'K20221 importin-4 | (RefSeq) KAP123, YRB4; karyopherin KAP123': 174.11,
#  'K06649 regulatory protein SWI4 | (RefSeq) SWI4, ART1; SBF complex DNA-binding subunit SWI4': 25.93,
#  'K12623 U6 snRNA-associated Sm-like protein LSm4 | (RefSeq) LSM4, SDB23, USS1; U6 snRNA complex subunit LSM4': 157.97,
#  'K17086 transmembrane 9 superfamily member 2/4 | (RefSeq) TMN3; Tmn3p': 37.09,
#  'no KO assigned | (RefSeq) BOI2, BEB1; Boi2p': 25.46,
#  'no KO assigned | (RefSeq) SPR6; Spr6p': 35.86,
#  'K22646 E3 ubiquitin-protein ligase complex SLX5-SLX8 subunit SLX8 [EC:2.3.2.27] | (RefSeq) SLX8; SUMO-targeted ubiquitin ligase complex subunit SLX8': 30.7,
#  'K02321 DNA polymerase alpha subunit B | (RefSeq) POL12; DNA-directed DNA polymerase alpha subunit POL12': 22.53,
#  'K02894 large subunit ribosomal protein L23e | (RefSeq) RPL23B; ribosomal 60S subunit protein L23B': 3142.41,
#  'K11246 SHO1 osmosensor | (RefSeq) SHO1, SSU81; osmosensor SHO1': 69.32,
#  'no KO assigned | (RefSeq) AVT6; aspartate/glutamate transporter': 10.13,
#  'no KO assigned | (RefSeq) SCS2; phosphatidylinositol-binding protein SCS2': 137.81,
#  'K12493 ADP-ribosylation factor GTPase-activating protein 2/3 | (RefSeq) GLO3; ADP-ribosylation factor GTPase-activating protein': 194.21,
#  'K19830 casein kinase I homolog 3 [EC:2.7.11.1] | (RefSeq) YCK3, CKI3; casein kinase YCK3': 70.92,
#  'no KO assigned | (RefSeq) DSE1; Dse1p': 279.55,
#  'K10591 E3 ubiquitin-protein ligase NEDD4 [EC:2.3.2.26] | (RefSeq) RSP5, HPG1, MDP1, MUT2, NPI1, SMM1, UBY1; NEDD4 family E3 ubiquitin-protein ligase': 117.73,
#  'K16578 CLIP-associating protein 1/2 | (RefSeq) STU1; Stu1p': 12.76,
#  'K14842 ribosome biogenesis protein NSA2 | (RefSeq) NSA2; rRNA-processing protein NSA2': 284.21,
#  'K14765 U3 small nucleolar ribonucleoprotein protein LCP5 | (RefSeq) LCP5; Lcp5p': 98.57,
#  'no KO assigned | (RefSeq) VFA1; Vfa1p': 26.64,
#  'K21157 SNF1-activating kinase 1 [EC:2.7.11.1] | (RefSeq) SAK1, PAK1; serine/threonine protein kinase SAK1': 57.17,
#  'K21545 C2H2 transcription facotor | (RefSeq) COM2; Com2p': 194.81,
#  'K02976 small subunit ribosomal protein S26e | (RefSeq) RPS26B; ribosomal 40S subunit protein S26B': 2833.32,
#  'no KO assigned | (RefSeq) PMD1; Pmd1p': 12.91,
#  'K06269 serine/threonine-protein phosphatase PP1 catalytic subunit [EC:3.1.3.16] | (RefSeq) GLC7, CID1, DIS2; type 1 serine/threonine-protein phosphatase catalytic subunit GLC7': 426.68,
#  'K17619 magnesium-dependent phosphatase 1 [EC:3.1.3.48 3.1.3.-] | (RefSeq) Mg-dependent acid phosphatase': 92.73,
#  'K01497 GTP cyclohydrolase II [EC:3.5.4.25] | (RefSeq) RIB1; GTP cyclohydrolase II': 80.01,
#  'K17255 Rab GDP dissociation inhibitor | (RefSeq) GDI1, SEC19; Gdi1p': 171.0,
#  'K20827 RNA polymerase II-associated protein 2 [EC:3.1.3.16] | (RefSeq) RTR1; RNA polymerase II subunit B1 CTD phosphatase RTR1': 39.65,
#  'no KO assigned | (RefSeq) EMP65; Emp65p': 30.6,
#  'K02259 heme a synthase [EC:1.17.99.9] | (RefSeq) COX15; Cox15p': 81.42,
#  'K01247 DNA-3-methyladenine glycosylase II [EC:3.2.2.21] | (RefSeq) MAG1, MMS5; DNA-3-methyladenine glycosylase II': 16.37,
#  'K11885 DNA damage-inducible protein 1 | (RefSeq) DDI1, VSM1; Ddi1p': 33.08,
#  'K18738 heterogeneous nuclear rnp K-like protein | (RefSeq) HEK2, KHD1; Hek2p': 104.61,
#  'no KO assigned | (RefSeq) GPB2, KRH1; Gpb2p': 39.67,
#  'K11839 ubiquitin carboxyl-terminal hydrolase 8 [EC:3.4.19.12] | (RefSeq) UBP5; putative ubiquitin-specific protease UBP5': 12.75,
#  'K07243 high-affinity iron transporter | (RefSeq) FTR1; high-affinity iron permease FTR1': 106.18,
#  'K12624 U6 snRNA-associated Sm-like protein LSm5 | (RefSeq) LSM5; RNA-binding protein LSM5': 187.4,
#  'K06673 cohesin loading factor subunit SCC4 | (RefSeq) SCC4; cohesin-loading factor complex subunit SCC4': 16.37,
#  'K03120 transcription initiation factor TFIID TATA-box-binding protein | (RefSeq) SPT15, BTF1, TBP1; TATA-binding protein': 257.45,
#  'no KO assigned | (RefSeq) PEA2, DFG9, PPF2; Pea2p': 47.02,
#  'no KO assigned | (RefSeq) SPI1; Spi1p': 48.8,
#  'no KO assigned | (RefSeq) SHE1; She1p': 20.8,
#  'K11841 ubiquitin carboxyl-terminal hydrolase 10 [EC:3.4.19.12] | (RefSeq) UBP3, BLM3; mRNA-binding ubiquitin-specific protease UBP3': 47.33,
#  'no KO assigned | (RefSeq) 2-aminoadipate transaminase': 37.2,
#  'K17668 protein PET122, mitochondrial | (RefSeq) PET122; Pet122p': 8.2,
#  'K03217 YidC/Oxa1 family membrane protein insertase | (RefSeq) OXA1; membrane insertase OXA1': 37.94,
#  ...}

# %%
# Create a new DataFrame by copying the original
results_df = fpkm_df.copy()

# %%
results_df['-log10p_GNSR_vs_GNHR'] = -np.log10(p_values_gnsr_vs_gnhr)
results_df['-log10p_GNSR_vs_GNUR'] = -np.log10(p_values_gnsr_vs_gnur)
results_df['-log10p_GNSR_vs_EBY'] = -np.log10(p_values_gnsr_vs_eby)


results_df.head()
# Out:
#                     Geneid   EBY_1   EBY_2   EBY_3  EBY-U_1  EBY-GNSR_1  \
# 0  jgi|Sacce1|1000|YDL018C   47.55   49.28   46.03    27.44       66.92
# 1  jgi|Sacce1|1001|YDL017W   20.11   20.75   19.72    26.48       25.70
# 2  jgi|Sacce1|1002|YDL016C    5.68    6.50    3.91     4.32        7.41
# 3  jgi|Sacce1|1003|YDL015C  258.04  263.32  271.20   176.40      287.94
# 4  jgi|Sacce1|1004|YDL014W  338.89  352.15  227.14    32.43      264.66
#
#    EBY-GNSR_2  EBY-GNHR_1  EBY-GNHR_2  EBY-GNHR_3  EBY-GNUR_1  EBY-GNUR_2  \
# 0       56.75       26.36       30.20       32.08       45.72       44.23
# 1       28.76       22.21       20.59       22.80       33.20       36.83
# 2        7.81        2.39        2.12        2.39        5.77        2.15
# 3      309.80       97.96      133.22      114.73      172.79      189.77
# 4      275.53       33.94       28.27       20.38       70.73      106.82
#
#    EBY-GNUR_3                         JGI_annotation  \
# 0       46.24                                    NaN
# 1       33.11                         Protein kinase
# 2        3.29                                    NaN
# 3      190.81  3-oxo-5-alpha-steroid 4-dehydrogenase
# 4       72.10                                    NaN
#
#                                      KEGG_annotation  -log10p_GNSR_vs_GNHR  \
# 0              no KO assigned | (RefSeq) ERP3; Erp3p              1.131358
# 1  K02214 cell division control protein 7 [EC:2.7...              0.873785
# 2                                                NaN              2.100257
# 3  K10258 very-long-chain enoyl-CoA reductase [EC...              2.598541
# 4  K14563 rRNA 2'-O-methyltransferase fibrillarin...              3.169231
#
#    -log10p_GNSR_vs_GNUR  -log10p_GNSR_vs_EBY
# 0              0.728756             0.679902
# 1              1.243445             0.902233
# 2              1.194204             1.041414
# 3              1.641508             0.787034
# 4              2.898651             0.336592

# %%
#the threshold for significant genes drastically changes how many there are in the sigfnificant gene lists, 5 seems like a reasonable approach 
threshold = 3


significant_genes_GNSR_vs_GNHR_df = results_df[results_df['-log10p_GNSR_vs_GNHR'] > threshold]
significant_genes_GNSR_vs_GNUR_df = results_df[results_df['-log10p_GNSR_vs_GNUR'] > threshold]
significant_genes_GNSR_vs_EBY_df = results_df[results_df['-log10p_GNSR_vs_EBY'] > threshold]

# %%
gene_list_gnsr_vs_gnhr = significant_genes_GNSR_vs_GNHR_df['Geneid'].tolist()
print(f"\nFound {len(gene_list_gnsr_vs_gnhr)} significant genes in the 'GNSR vs GNHR' comparison.")
print(gene_list_gnsr_vs_gnhr[:10])

gene_list_gnsr_vs_gnur = significant_genes_GNSR_vs_GNUR_df['Geneid'].tolist()
print(f"\nFound {len(gene_list_gnsr_vs_gnur)} significant genes in the 'GNSR vs GNUR' comparison.")
print(gene_list_gnsr_vs_gnur[:10])

gene_list_gnsr_vs_eby = significant_genes_GNSR_vs_EBY_df['Geneid'].tolist()
print(f"\nFound {len(gene_list_gnsr_vs_eby)} significant genes in the 'GNSR vs EBY' comparison.")
print(gene_list_gnsr_vs_eby[:10])
# Out:
# Found 975 significant genes in the 'GNSR vs GNHR' comparison.
# ['jgi|Sacce1|1004|YDL014W', 'jgi|Sacce1|1014|YDL005C', 'jgi|Sacce1|1019|YDR001C', 'jgi|Sacce1|1020|YDR002W', 'jgi|Sacce1|1026|YDR007W', 'jgi|Sacce1|1041|YDR021W', 'jgi|Sacce1|1043|YDR023W', 'jgi|Sacce1|1050|YDR030C', 'jgi|Sacce1|1053|YDR033W', 'jgi|Sacce1|1056|YDR034W-B']
#
# Found 679 significant genes in the 'GNSR vs GNUR' comparison.
# ['jgi|Sacce1|1008|YDL010W', 'jgi|Sacce1|1014|YDL005C', 'jgi|Sacce1|1015|YDL004W', 'jgi|Sacce1|1019|YDR001C', 'jgi|Sacce1|1020|YDR002W', 'jgi|Sacce1|1022|YDR003W-A', 'jgi|Sacce1|1025|YDR006C', 'jgi|Sacce1|1026|YDR007W', 'jgi|Sacce1|1048|YDR028C', 'jgi|Sacce1|1051|YDR031W']
#
# Found 581 significant genes in the 'GNSR vs EBY' comparison.
# ['jgi|Sacce1|1027|YDR008C', 'jgi|Sacce1|1028|YDR009W', 'jgi|Sacce1|1039|YDR019C', 'jgi|Sacce1|1069|YDR047W', 'jgi|Sacce1|1077|YDR055W', 'jgi|Sacce1|107|YAR050W', 'jgi|Sacce1|1082|YDR060W', 'jgi|Sacce1|1084|YDR062W', 'jgi|Sacce1|1092|YDR070C', 'jgi|Sacce1|10|YAL064W']

# %%
fpkm_df[['Geneid'] == 'jgi|Sacce1|1004|YDL014W']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 fpkm_df[['Geneid'] == 'jgi|Sacce1|1004|YDL014W']
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: False

# %%
def get_de_genes(df, group1_cols, group2_cols, p_value_threshold=0.05):
    p_values = stats.ttest_ind(
        df[group1_cols],
        df[group2_cols],
        axis=1,
        equal_var=False,
        nan_policy='omit'
    ).pvalue
    significant_df = df[p_values < p_value_threshold]
    return significant_df['Geneid'].tolist()

# Define the column groups for your conditions
eby_cols = ['EBY_1', 'EBY_2', 'EBY_3']
gnsr_cols = ['EBY-GNSR_1', 'EBY-GNSR_2']
gnhr_cols = ['EBY-GNHR_1', 'EBY-GNHR_2', 'EBY-GNHR_3']
gnur_cols = ['EBY-GNUR_1', 'EBY-GNUR_2', 'EBY-GNUR_3']

# Generate the three lists of differentially expressed genes
gnsr_vs_gnhr_genes = get_de_genes(fpkm_df, gnsr_cols, gnhr_cols)
gnsr_vs_gnur_genes = get_de_genes(fpkm_df, gnsr_cols, gnur_cols)
gnsr_vs_eby_genes = get_de_genes(fpkm_df, gnsr_cols, eby_cols)


# --- CORRECTED PLOTTING AND SAVING ---

# Change 1: Explicitly create a new figure and axes for this specific plot
fig, ax = plt.subplots(figsize=(8, 8))

# Change 2: Tell venn3 exactly which axes to draw on by passing ax=ax
venn3(
    [set(gnsr_vs_gnhr_genes), set(gnsr_vs_gnur_genes), set(gnsr_vs_eby_genes)],
    set_labels=('GNSR vs GNHR', 'GNSR vs GNUR', 'GNSR vs EBY'),
    ax=ax
)

ax.set_title("Differentially Expressed Genes Across Comparisons (p < 0.05)")

# Change 3: Save the figure BEFORE showing it
fig.savefig('venn_diagram.pdf', bbox_inches='tight')

# Now, display the plot
plt.show()
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:611: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)
# /home/codespace/.local/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:611: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)
# /home/codespace/.local/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:611: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Define the column groups
eby_cols = ['EBY_1', 'EBY_2', 'EBY_3']
gnsr_cols = ['EBY-GNSR_1', 'EBY-GNSR_2']
gnhr_cols = ['EBY-GNHR_1', 'EBY-GNHR_2', 'EBY-GNHR_3']
gnur_cols = ['EBY-GNUR_1', 'EBY-GNUR_2', 'EBY-GNUR_3']

# 1. PRE-CALCULATE P-VALUES (Efficient approach)
p_vals1 = stats.ttest_ind(fpkm_df[gnsr_cols], fpkm_df[gnhr_cols], axis=1, nan_policy='omit').pvalue
p_vals2 = stats.ttest_ind(fpkm_df[gnsr_cols], fpkm_df[gnur_cols], axis=1, nan_policy='omit').pvalue
p_vals3 = stats.ttest_ind(fpkm_df[gnsr_cols], fpkm_df[eby_cols], axis=1, nan_policy='omit').pvalue

# Create pandas Series to easily link p-values with Geneids
p_series1 = pd.Series(p_vals1, index=fpkm_df['Geneid'])
p_series2 = pd.Series(p_vals2, index=fpkm_df['Geneid'])
p_series3 = pd.Series(p_vals3, index=fpkm_df['Geneid'])

# 2. CREATE THE PLOT LAYOUT
# Make space at the bottom for the slider
fig, ax = plt.subplots(figsize=(8, 9))
plt.subplots_adjust(bottom=0.2)

# 3. DEFINE THE UPDATE FUNCTION
def update(p_value_threshold):
    # a. Filter genes based on the new threshold
    set1 = set(p_series1[p_series1 < p_value_threshold].index)
    set2 = set(p_series2[p_series2 < p_value_threshold].index)
    set3 = set(p_series3[p_series3 < p_value_threshold].index)

    # b. Clear the previous Venn diagram
    ax.clear()

    # c. Draw the new Venn diagram
    venn3(
        [set1, set2, set3],
        set_labels=('GNSR vs GNHR', 'GNSR vs GNUR', 'GNSR vs EBY'),
        ax=ax
    )
    ax.set_title(f"Differentially Expressed Genes (p < {p_value_threshold:.3f})")
    fig.canvas.draw_idle()

# 4. CREATE THE SLIDER
slider_ax = fig.add_axes([0.20, 0.05, 0.65, 0.03]) # [left, bottom, width, height]
p_val_slider = Slider(
    ax=slider_ax,
    label='P-value Threshold',
    valmin=0.001,
    valmax=0.1,
    valinit=0.05, # Initial p-value
    valfmt='%1.3f'
)

# 5. CONNECT THE SLIDER TO THE UPDATE FUNCTION
p_val_slider.on_changed(update)

# 6. INITIAL DRAW
update(0.05)

plt.show()
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:611: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)
# /home/codespace/.local/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:611: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)
# /home/codespace/.local/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:611: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
p_values_for_gif = np.linspace(0.1, 0.001, num=30) # 30 frames from 0.1 down to 0.001

# Define the animation function
def animate_slider(p_val):
    # Update the Venn diagram by calling the existing function
    update(p_val)
    # Update the slider's visual position
    p_val_slider.set_val(p_val)

# Create the animation
ani_slider = animation.FuncAnimation(
    fig, 
    animate_slider, 
    frames=p_values_for_gif,
    interval=150 # 150ms delay between frames
)

# Save the animation as a GIF
ani_slider.save('slider_animation.gif', writer='pillow', fps=10)
print("Slider GIF saved!")
# Out:
# Slider GIF saved!
